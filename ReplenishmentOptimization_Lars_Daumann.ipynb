# %% [markdown]
# Die Funktionsweise des entwickelten genetischen Algorithmus wird hier schrittweise erläutert. Jedes Kapitel beschreibt das Vorgehen einer Funktion und zeigt es an einem praktischen Beispiel. Die Kapitel 1 bis 8 beziehen sich auf die einzelnen Teile des Algorithmus, welche in Kapitel 9 durch den Hauptteil zusammengeführt werden. Kapitel 10 erläutert das mehrfache Ausführen des Algorithmus. Das letzte Kapitel geht auf die Frage ein, inwiefern sich die Implementierung für größere Datenmengen eignet.
#
# Da der Algorithmus mit Zufallsvariablen arbeitet, wird ein Seed verwendet, um Ergebnisse nachvollziehbar reproduzieren zu können. Die Nummer für den Seed wird vor jedem Beispiel definiert und lässt sich ändern, um andere Verläufe zu generieren. Die in der Arbeit beschriebene Generation basiert auf der Population, welche mit der Seed-Nummer 3 generiert wird. Alle anschließenden Schritte folgen aus der Seed-Nummer 1.

# %% [markdown]
# # 1. Imports

# %% [markdown]
# Der Algorithmus verwendet verschiedene Bibliotheken. Zur Verarbeitung von Daten mit Arrays benutzt er *NumPy*, welches eine effiziente Manipulation von Datenstrukturen ermöglicht. *Itertools* ermöglicht es bei der Berechnung der Fitness-Werte die Iteration in manuell festgelegten Schritten festzulegen. Wenn Objekte kopiert werden und diese Kopie verändert wird, wird *Copy* verwendet, um das eigentliche Objekt nicht zu verändern. Pyplot dient zur Darstellung von Werten in Grafiken. Um die Integrität der Ergebnisse zu gewährleisten, wird die Funktion `exit()` von der Bibliothek *Sys* angewendet. Sobald die Werte der Population nicht mehr den Anforderungen des Algorithmuses entsprechen, beendet `exit()` den Durchlauf. *Time* dient zur Laufzeitmessung.

# %%
import numpy as np
import itertools as it
import copy as cp
import matplotlib.pyplot as plt
import sys
import time

# %% [markdown]
# # 2. Initialisierung

# %% [markdown]
# Dieser Abschnitt initialisiert die wesentlichen Variablen und Ausgangswerte.

# %%
#  Werte, die verändert werden können
seed_number = 3
np.random.seed(seed_number)
selling_price = np.array([13, 9])  # Verkaufspreise der Produkte: P1 kostet 13, P2 9 Einheiten
supplier_price = np.array([[6, 4], [4, 3]])  # Lieferantenpreise der Produkte: [6, 4] bedeutet, dass P1 von L1 6 Einheiten kostet und P2 von L1 4 Einheiten kostet
transaction_cost = np.array([10, 30])  # Transaktionkosten der Lieferanten: L1 kostet 10, L2 30 Einheiten
holding_cost = np.array([30, 20])  # Lagerkosten für die Produkte: P1 kostet 30, P2 20 Einheiten
demands = np.array([30, 14])  # Nachfrage der Produkte: Nachfrage für P1 ist 30, für P2 14 Einheiten
number_products = len(selling_price)  # Anzahl an Produkten, abhängig von selling_price
number_suppliers = len(supplier_price)  # Anzahl an Lieferanten, abhängig von supplier_price
population_size = 3  # Populationsgröße
lower_bound = 0  # Untere Grenze für Werte zur Mutation
upper_bound = np.array([50, 34])  # Obere Grenze für Werte zur Mutation des jeweiligen Produktes: ein Gen von P1 kann bei der Mutation maximal den Wert 50 annehmen
number_iterations = 1  # Anzahl an Iterationen
number_generations = 15  # Anzahl an Generationen
penalty = 99999  # Strafe, wenn Chromosom nicht Anforderungen erfüllt

chromosome_size = number_suppliers * number_products  # Chromosomgröße
init_population = np.zeros((population_size, chromosome_size))  # Ausgangspopulation, zunächst nur aus Chromosomen mit 0 als Genen
number_parents = (population_size // 2) + (population_size % 2)  # Anzahl der Eltern, abhängig von der Populationsgröße
number_children = (population_size - number_parents)  # Anzahl der Nachfolger, abhängig von der Populationsgröße

#  Variablen zum Speichern und Analysieren
population_before = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Anfang einer Generation
population_fitness_before = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Anfang einer Generation
population_after = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Ende einer Generation
population_fitness_after = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Ende einer Generation
population_fitness_after_sum = np.zeros((number_iterations, number_generations))  # alle Summen der Fitness-Werte jeder Population am Ende einer Generation
best_chromosomes_after = np.zeros((number_iterations, number_generations, chromosome_size))  # alle besten Chromosome jeder Generation
best_fitness_after = np.zeros((number_iterations, number_generations))  # alle Fitness-Werte der besten Chromosome jeder Generation
best_chromosome_of_iteration = np.zeros((number_iterations, chromosome_size))  # die besten Chromosome jeder Iteration
best_fitness_of_iteration = np.zeros(number_iterations)  # bester Fitness-Wert jeder Iteration

parents_list = np.zeros((number_iterations, number_generations, number_parents, chromosome_size))  # Liste aller Eltern
crossover_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Kreuzungen
tries_crossover_list = np.zeros((number_iterations, number_generations, number_children))  # Liste aller Versuchsanzahlen zur Kreuzung
mutation_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Mutationen
tries_mutation_list = np.zeros((number_iterations, number_generations, number_children))  # Lister aller Versuchsanzahlen zur Mutation

costs_list = np.zeros((number_iterations, number_generations, population_size, 4))  # Liste der einzelnen Kosten jeder Population
costs_max_list = np.zeros((number_iterations, number_generations, 4))  # Liste der einzelnen Kosten der besten Chromosome jeder Generation
costs_sum_list = np.zeros((number_iterations, number_generations, 4))  # Liste der Summe der Kosten jeder Generation

# %% [markdown]
# Produkte: | Produkt 1 | Produkt 2
# --- | --- | ---
# Verkaufspreis: |   13 | 9
# Lagerkosten: | 30 | 20
# Nachfrage | 30 | 14
#
#
# Kosten für jeden Lieferanten: | Produkt 1 | Produkt 2
# --- | --- | ---
# Lieferant 1 | 6 | 4
# Lieferant 2 | 4 | 3
#
# Transaktionskosten: | Lieferant 1 | Lieferant 2
# --- | --- | ---
#     | 10 | 30

# %% [markdown]
# # 3. Ausgangspopulation

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `random_population()` erzeugt eine zufällige Population aus `population_size` unterschiedlichen Chromosomen mit der Länge `chromosome_size`. Ausgehend von einer Population, die nur aus Chromosomen mit den Genen 0 besteht, erfolgt die Erstellung der einzelnen Chromosome nacheinander. Da ein Chromosom nur dann eine gültige Lösung darstellt, wenn die Nachfrage befriedigt wird, müssen die zufälligen Gene überprüft werden. Die Variable `sum_elements_product` speichert Summe der bestellten Menge eines Produkts. Ist diese Summe kleiner als die Nachfrage werden neue Werte solange generiert, bis das Chromosom die Bedingung für dieses Produkt erfüllt. Um gültige Produktmengen zu erzeugen, kann einem Gen ein zufälliger Wert von 0 bis zur Nachfrage zugeordnet werden. Mittels der Variable `product_index` erfolgt der Zugriff auf die für das Produkt relevante Stellen. Sind die Gene für ein Produkt zulässig, erhöht sich `product_index` um die Anzahl an Lieferanten und die Mengen für das nächste Produkt werden ermittelt. Anschließend wird das Chromosom in der Population gespeichert und das nächste Chromosom wird generiert. Die Methode gibt die Population zurück.

# %%
def random_population():
    population_random = np.zeros(
        (population_size, chromosome_size))  # Ausgangspopulation, bestehend aus Chromosomen mit 0 als Gene
    for population_index in range(population_size):
        init_chromosome = np.zeros(chromosome_size)
        product_index = 0
        for product in range(number_products):  # Ermitteln der Werte für jedes Produkt
            # Die Summe der Produktmengen besteht aus dem Intervall von product_index bis product_index + number_suppliers
            sum_elements_product = sum(init_chromosome[product_index: product_index + number_suppliers])
            demand_product = demands[product]  # Nachfrage des entsprechenden Produkts
            while sum_elements_product < demand_product:  # Generierung neuer Werte solange die bestellte Menge kleiner als die Nachfrage ist
                for supplier in range(number_suppliers):  # Jedes für das entsprechende Produkt relevante Gen erhält einen zufälligen Wert
                    init_chromosome[product_index + supplier] = np.random.randint(0, demand_product)
                sum_elements_product = sum(
                    init_chromosome[product_index: product_index + number_suppliers])  # Ermittlung der neuen Summe
            product_index += number_suppliers  # Erhöhung des Indexes um die Anzahl an Lieferanten, um das nächste Produkt zu bearbeiten
        population_random[population_index] = init_chromosome  # Speichern des Chromosoms
    return population_random

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Die in der Arbeit vorgestellte Population generiert der Algorithmus mit `seed_number` = 3.

# %%
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()
print(example_population)
# Out:
# [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]

# %% [markdown]
# # 4. Fitness-Wert

# %% [markdown]
# ## Funktionen
# Der Fitness-Wert eines Chromosoms ist abhängig von dem Verkaufspreis, dem Einkaufspreis, den Transaktionskosten und den Lagerkosten. Damit Chromosome mit negativen Fitness-Werten in der späteren Selektion nicht berücksichtigt werden, ordnet die Funktion ihnen den Fitness-Wert 0 zu.

# %%
def calculate_fitness(chrom):
    sum_selling_price_demand = calculate_total_revenue()
    sum_supplier_price = calculate_purchase_cost(chrom)
    sum_transaction_cost = calculate_transaction_cost(chrom)
    sum_holding_cost = calculate_holding_cost(chrom)
    fitness = sum_selling_price_demand - sum_supplier_price - sum_transaction_cost - sum_holding_cost
    #  Die Roulette Wheel Selection verhindert das Auswählen von Chromosomen, deren Fitness 0 ist.
    if fitness < 0:
        fitness = 0
    return fitness

# %% [markdown]
# Die Funktion `calculate_total_revenue()` berechnet den totalen Umsatz aller Produkte. Der Umsatz eines Produktes ergibt sich aus der Multiplikation von Nachfrage (`demands[product]`) und Verkaufspreis (`selling_price[product]`). Die Summe aller Umsätze wird in der Variable `revenue` gespeichert und zurückgegeben.

# %%
def calculate_total_revenue():
    revenue = 0
    for product in range(number_products):
        # Dem bisherigen Umsatz wird der Umsatz dieses Produktes hinzugefügt
        revenue += (demands[product] * selling_price[product])  
    return revenue

# %% [markdown]
# Die Funktion `calculate_purchase_cost(chrom)` definiert die Einkaufskosten eines Chromosoms. Für jedes Produkt werden die Kosten durch die Multiplikation der Menge mit dem Lieferantenpreis ermittelt. Die Summe daraus ergibt die Einkaufskosten insgesamt.

# %%
def calculate_purchase_cost(chrom):
    product_index = 0
    purchase = 0
    for product in range(number_products):
        for supplier in range(number_suppliers):
            # Den bisherigen Kosten werden die Kosten von einem Lieferanten hinzugefügt
            purchase += chrom[product_index] * supplier_price[supplier][product]
            product_index += 1
    return purchase

# %% [markdown]
# Die Transaktionskosten eines Chromosoms werden durch die Funktion `calculate_transaction_cost(chrom)` bestimmt. Transaktionskosten treten auf, wenn von einem Lieferanten mindestens ein Produkt bezogen wird. Die Kosten sind also unabhängig davon, ob ein oder mehrere Produkte bestellt werden. Hier überprüft die Methode nun alle Lieferanten nacheinander. Mittels der Funktion `islice()` ermittelt der Algorithmus die insgesamt bestellte Menge bei einem Lieferanten. Ist diese größer als 0, treten die einmaligen Transaktionskosten des jeweiligen Lieferanten auf. Die Summe dieser Kosten wird als `transaction` zurückgegeben.

# %%
def calculate_transaction_cost(chrom):
    transaction = 0
    for supplier in range(number_suppliers):
        # Die Summe wird im Bereich von supplier bis chromosome_size in Schritten der Größe number_suppliers ermittelt
        sum_supplier_product = sum(it.islice(chrom, supplier, chromosome_size, number_suppliers))  
        if sum_supplier_product != 0:
            transaction += transaction_cost[supplier]
    return transaction

# %% [markdown]
# Lagerkosten treten für Produkte auf, die nicht verkauft wurden und im Lager vorrätig bleiben. Die Funktion `calculate_holding_cost(chrom)` bestimmt für jedes Produkt die übrige Menge `remaining_quantity_product` und leitet daraus die Lagerkosten `sum_holding_cost` her. Gleichzeitig überprüft die Funktion die Bedingung, ob die Nachfrage gedeckt wird. Ist `remaining_quantity_product` negativ, sind weniger Produkte vorhanden als notwendig. Die Funktion gibt den Wert von `penalty` zurück. Ist dies nicht der Fall erhöht sich `sum_holding_cost` um die Lagerkosten des Produkts.

# %%
def calculate_holding_cost(chrom):
    sum_holding_cost = 0
    product_index = 0
    for product in range(number_products):
        #  Menge eines Produktes besteht aus der Summe des Intervalls von product_index bis product_index + number_suppliers
        quantity_product = np.sum(chrom[product_index:product_index + number_suppliers])
        #  Differenz aus vorhandener Produktmenge und Nachfrage des Produkts
        remaining_quantity_product = quantity_product - demands[product]
        #  Übrigen Produktmengen multipliziert mit den Lagerkosten des entsprechenden Produktes
        remaining_holding_cost = remaining_quantity_product * holding_cost[product]
        #  Erhöhen des Indexes für das nächste Produkt
        product_index += number_suppliers
        #  Sind die Lagerkosten negativ, ist die Bestellmenge kleiner als die Nachfrage und die Lösung nicht zulässig
        if remaining_holding_cost < 0:
            return penalty
        else:
            sum_holding_cost += remaining_holding_cost
    return sum_holding_cost

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Der Fitness-Wert des Chromosoms $[25, 9, 10, 5]$ ist 95. Der Umsatz des ist abhängig von der Nachfrage und dem Verkaufsspreis. Er ergibt sich aus folgenden Gleichungen.
#
# Die Berechnung beginnt mit der Ermittlung des Umsatzes. Dieser ist konstant für alle Chromosome und berechnet sich wie folgt:
#
# $ TU = 13 * 30 + 9 * 14 = 516 $
#
# Im zweiten Schritt wird der Einkaufspreis festgestellt. Der Algorithmus geht
# hier produktweise vor.
#
# $ EP_{1} = 25 * 6 + 9 * 4 = 186 $
#
# $ EP_{2} = 10 * 4 + 5 * 3 = 55 $
#
# $ EP = EP_{1} + EP_{2} = 186 + 55 = 241 $
#
# Die Transaktionskosten werden hingegen lieferantenweise bestimmt. Alle Gene,
# die in Verbindung mit einem Lieferanten stehen, haben einen Abstand von der
# Lieferantenanzahl. Für $L_{1}$ sind die Gene 25 und 10 relevant. Die Summe ist
# größer als 0, sodass einmalige Transaktionskosten anfallen. Die Menge, die der
# Händler von Lieferant $L_{2}$ bezieht, ist 14. Die Transaktionskosten lauten nun wie
# folgt:
#
# $ TK = 10 + 30 = 40 $
#
# Den letzten Faktor bilden die Lagerkosten. Das Verfahren erfolgt produktweise,
# da die gesamte Menge eines Produkts relevant ist. Aus der Differenz dieser Menge und der Nachfrage entsteht die überschüssige Menge. Multipliziert man
# die Differenz mit dem Kostensatz, kommt man auf die Lagerkosten. Für die
# Produkte $P_{1}$ und $P_{2}$ gelten folgende Lagerkosten.
#
# $ LK_{1} = ((25 + 9) - 30) * 30 = 120 $
#
# $ LK_{2} = ((10 + 5) - 14) * 20 =  20 $
#
# $ LK = 120 + 20 = 140 $
#
# Ein Chromosom, das die Nachfrage nicht bedienen kann, besitzt negative Lagerkosten. Das Chromosom $C_{BSP} = [25, 9, 3, 5]$ kann die Nachfrage für Produkt $P_{2}$ nicht erfüllen. In diesem Fall ordnet der GA dem Chromosom Lagerkosten von 99999 zu, sodass der Fitness-Wert garantiert negativ ist.
#
# $ LK_{BSP2} = ((2 + 5) − 14) ∗ 20 = −140 < 0 ⇒ LK = 99999 $
#
# Die Differenz der einzelnen Kosten bildet den Gewinn.
#
# $ \pi = TU - (EP + TK + LK) = 516 - 241 - 40 - 140 = 95 $
#
# Um in der späteren Selektion nur Chromosome mit positiven Werten zu berücksichtigen, werden alle Fitness-Werte, die kleiner als 0 sind, auf 0 gesetzt. Dies ist bei Chromosom $C_{2}$ der Fall.
#
# $ \pi_{C2} = 516 − 323 − 40 − 680 = −527 < 0 ⇒ π = 0$

# %%
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()
print(example_population)
for solution in example_population:
    print ("Fitness of chromosome", solution, "=", calculate_fitness(solution))
# Out:
# [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness of chromosome [10. 24.  8.  8.] = 104.0
# Fitness of chromosome [29. 19. 10. 11.] = 0
# Fitness of chromosome [25.  9. 10.  5.] = 95.0

# %% [markdown]
# # 5. Selektion

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `select_parents(fitness, number, pop)` wählt `number_parents` Chromosome als Eltern aus. Die Selektion ist abhängig von den Fitness-Werten, sodass Chromosome mit einem hohen Fitness-Werte eine höhere Warscheinlichkeit zur Auswahl besitzen. Die merfache Auswahl eines Chromosoms ist nur dann möglich, wenn nicht ausreichend viele Chromosome mit positiven Fitness-Werten vorhanden sind. In diesem Fall wählt der Algorithmus das erstgewählte Chromosom erneut aus. Daraus folgt, dass mindestens eine Lösung mit positiven Ergebnissen existieren muss. Ist dies nicht der Fall stoppt der Algorithmus.
#
# Die Methode benötigt eine Liste mit Fitness-Werten `fitness`, eine Anzahl an Eltern `number` und eine Population `pop`. Ausgehend von den übergebenen Parametern überprüft die Funktion zunächst, ob ein Chromosom mit positivem Fitness-Wert vorhanden ist. Anschließend erzeugt er eine leere Population `parents_new` und erzeugt `number` Eltern. Hier wird die Funktion `select_parents_roulette()` aufgerufen, welche ein Chromosom als Elternteil auswählt. Das Chromosom wird aus `pop` und `fitness` entfernt, damit es nicht erneut ausgewählt werden kann.

# %%
def select_parents(fitness, number, pop):
    #  Überprüfen, ob positive Chromosome vorhanden sind
    if sum(fitness) == 0:
        print("No positive values")
        sys.exit()

    parents_new = np.empty((number, chromosome_size), dtype=int)
    #  Auswählen von number Eltern
    for parent_counter in range(0, number):
        #  Wenn kein positives Chromosom vorhanden ist, wird das erstgewählte Chromosom kopiert
        #  Durch die vorherige Überprüfung ist dies erst nach der erfolgreichen Selektion eines Chromosoms möglich
        if np.sum(fitness) == 0:
            parents_new[parent_counter] = parents_new[0]
        else:
            #  Auswählen eines Chromosoms durch die Roulette Wheel Selection
            parents_new[parent_counter] = select_parents_roulette(fitness, pop)
            #  Hilfsfunktion zum Ermitteln des Indexes eines Chromosoms in der Population
            index_delete_element = delete_element_from_lists(pop, parents_new[parent_counter])
            #  Entfernen des Chromosoms aus der Fitness-Liste und der Population
            pop = np.delete(pop, index_delete_element, axis=0)
            fitness = np.delete(fitness, index_delete_element, axis=0)
    return parents_new

# %% [markdown]
# Die Funktion `delete_element_from_lists(pop, element)` dient als Hilfsfunktion und gibt den Index eines Chromosoms aus. Wird dieses Element nicht gefunden, stoppt der Algorithmus.

# %%
def delete_element_from_lists(pop, element):
    #  Überprüft schrittweise, ob ein Element dem gesuchten Element entspricht
    for pos in range(len(pop)):
        check = np.equal(pop[pos], element)
        #  Wurde das Element gefunden, gibt die Methode den Index zurück
        if np.all(check == True):
            index_delete_element = pos
            return index_delete_element
    print("Delete not successfull")
    sys.exit()

# %% [markdown]
# Die Funktion `select_parents_roulette(fitness, pop)` gibt den Index eines Elementes aus, welches durch die *Roulette Wheel Selection* ausgewählt wurde. In dieser Methode werden alle Fitness-Werte summiert und bilden jeweils Intervalle. Eine zufällige Zahl zwischen 0 und der Summe ermittelt das ausgewählte Chromosom.
#
# Mittels der Fitness-Liste `fitness` und der Population `pop` ermittelt die Funktion die Summe der Fitness-Werte. Ist diese Summe 0, bricht der Algorithmus ab. Anschließend generiert die Methode eine zufällige Zahl `selector` und überprüft, in welchem Intervall diese Zahl liegt. In der while-Schleife geht der Algorithmus jedes Intervall solange durch, bis das Intervall gefunden wurde.

# %%
def select_parents_roulette(fitness, pop):
    #  Überprüfen, ob positive Chromosome vorhanden sind
    sum_fitness = np.sum(fitness)
    if sum_fitness == 0:
        print("No sum of fitness")
        sys.exit()

    #  Zahl zum Auswählen des Chromosoms
    selector = np.random.randint(1, sum_fitness)
    print("Find interval of", selector)
    find_interval = False
    sum_elements = 0
    counter = 0
    #  liegt die Zahl zwischen 0 und dem ersten Fitness-Wert, wird das entsprechende Chromosom ausgewählt.
    #  Wenn nicht addiert die Methode zum ersten Fitness-Wert den nächsten Fitness-Wert und überprüft, ob die Zahl kleiner als diese Summe ist.
    #  Dieser Prozess wiederholt sich solange, bis das Chromosom gefunden wurde.
    while not find_interval:
        if selector <= sum_elements + fitness[counter]:
            find_interval = True
        else:
            sum_elements += fitness[counter]
            counter += 1
    return pop[counter]

# %% [markdown]
# ## Beispiel

# %%
#  Population
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()

example_fitness_list = np.array([0, 0, 0])
example_counter = 0
for example_chromosome in example_population:
    example_fitness_list[example_counter] = calculate_fitness(example_chromosome)
    example_counter += 1

print ("Example population:", example_population)
print ("Example fitness:", example_fitness_list)

#  Eltern
seed_number = 1
np.random.seed(seed_number)
example_parents = select_parents(example_fitness_list, number_parents, example_population)
print ("Select", number_parents, "parents.","Example parents:", example_parents)
# Out:
# Example population: [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Example fitness: [104   0  95]
# Find interval of 38
# Find interval of 13
# Select 2 parents. Example parents: [[10 24  8  8]
#  [25  9 10  5]]

# %% [markdown]
# # 6. Crossover

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `cross_parents_uniform(cross_parents, boundary_iterations, gen, iteration)` erstellt neue Chromosome durch das Kreuzen von zwei Eltern. Jedes Gen der Eltern wird mit einer Wahrscheinlichkeit von 50% übernommen. Die Eltern werden solange gekreuzt, bis die Fitness des Nachfolgers positiv ist. Der Nachfolger kann vollständig einem Elternteil entsprechen. Die Kreuzung unterscheidet sich abhängig von der größe der Population. Ist die Größe ungerade, kreuzen sich die Elternteile nacheinander. Ist die Größe gerade, kreuzen sich zusätlich das letzte und das erste Elternteil.
#
# `cross_parents_uniform` arbeitet mit den Eltern `cross_parents`, einer Abbruchbedingung `boundary_iterations`, der akuellen Generation `gen` und der entsprechenden Iteration `iteration`.

# %%
def cross_parents_uniform(cross_parents, boundary_iterations, gen, iteration):
    crossover_children = np.empty((number_children, chromosome_size), dtype=int)
    # Erstellen von number_children Nachfolgern
    for index in range(number_children):
        child = np.full(chromosome_size, 0)
        limit = 0
        #  Kreuzen der Eltern solange der Nachfolger negativ ist und die maximale Anzahl an Versuchen nicht erreicht wurde
        while calculate_fitness(child) <= 0 and limit < boundary_iterations:
            #  Der erste Fall tritt ein, wenn die Anzahl der Eltern ungerade ist.
            #  Der zweite Fall tritt ein, wenn die Anzahl der Eltern gerade ist und der Index dem letzten Elterteil entspricht.
            if index != len(cross_parents) - 1:
                first_parent = cross_parents[index]
                second_parent = cross_parents[index + 1]
            else:
                first_parent = cross_parents[index]
                second_parent = cross_parents[0]
            #  Generieren der Gene des Nachfolgers
            for each_number in range(len(child)):
                #  Zufällige Variable p ist entweder 0 oder 1.
                #  Ist p = 0, wird das Gen des ersten Elternteils übernommen.
                p = np.random.randint(0, 2)
                if p < 0.5:
                    child[each_number] = first_parent[each_number]
                else:
                    child[each_number] = second_parent[each_number]
            #  Das Gen wird dem Chromosom an der Stelle index zugeordnet
            crossover_children[index] = child
            limit += 1

            #  Wird die maximale Anzahl an Versuchen erreicht, wird ein Elternteil vollständig kopiert
            if limit == boundary_iterations:
                random_choice = np.random.randint(0, 2)
                crossover_children[index] = cp.copy(cross_parents[index + random_choice])
        tries_crossover_list[iteration][gen][index] = limit
    return crossover_children

# %% [markdown]
# ## Beispiel

# %%
#  Population
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()

example_fitness_list = np.array([0, 0, 0])
example_counter = 0
for example_chromosome in example_population:
    example_fitness_list[example_counter] = calculate_fitness(example_chromosome)
    example_counter += 1

print("Example population:", example_population)
print("Example fitness:", example_fitness_list)

#  Eltern
seed_number = 1
np.random.seed(seed_number)
example_parents = select_parents(example_fitness_list, number_parents, example_population)
print ("Select", number_parents, "parents.","Example parents:", example_parents)

#  Kreuzung
example_crossover = cross_parents_uniform(example_parents, 100, 0, 0)
print("Parents:", example_parents)
for crossed in example_crossover:
  print("Crossover:", crossed)
# Out:
# Example population: [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Example fitness: [104   0  95]
# Find interval of 38
# Find interval of 13
# Select 2 parents. Example parents: [[10 24  8  8]
#  [25  9 10  5]]
# Parents: [[10 24  8  8]
#  [25  9 10  5]]
# Crossover: [25  9  8  8]

# %% [markdown]
# # 7. Mutation

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `mutate_crossover(cross, boundary_iterations, gen, iteration)` mutiert Chromosome solange, bis deren Fitness größer als vorher ist. Bei der Mutation wird ein beliebiges Gen durch eine zufällige Zahl ausgetauscht. Die zufällige Zahl ist dabei abhängig vom betroffenem Produkt. Zunächst sucht der Algorithmus ein zufälliges Produkt aus. Ausgehend vom Produkt wird ein zufälliges Gen ausgewählt und mutiert. Um unnötig hohe Werte zu vermeiden, ist die obere Grenze für jedes Produkt die Nachfrage plus 20. Findet der Algorithmus nach `boundary_iterations` keine bessere Mutation, wird die Kreuzung nicht verändert.

# %%
def mutate_crossover(cross, boundary_iterations, gen, iteration):
    mutation_crossover = np.empty((len(cross), chromosome_size), dtype=int)
    #  Mutieren von jedem Nachfolger
    for index in range(len(cross)):
        fit = calculate_fitness(cross[index])
        child = np.full(chromosome_size, 0)
        limit = 0
        #  Mutieren solange Fitness kleiner als vorher ist und die maximale Anzahl an Versuchen nicht erreicht ist
        while calculate_fitness(child) <= fit and limit < boundary_iterations:
            child = cp.copy(cross[index])
            #  Zufällige Zahl entscheidet, welches Produkt mutiert wird
            random_product = np.random.randint(0, number_products)
            #  Index der ersten Stelle des Produktes
            first_element = random_product * number_suppliers
            #  Indexes der Gene des Produktes
            list_element_indexes = np.arange(first_element, first_element + number_suppliers)
            #  Auswahl eines zufälligen Indexes des ausgewählten Produktes
            random_position = np.random.choice(list_element_indexes, 1, False)
            #  Mutation dieser Stelle durch eine zufällige Zahl zwischen 0 und der entsprechenden Grenze
            number_mutation = np.random.randint(lower_bound, upper_bound[random_product])
            child[random_position] = number_mutation
            limit += 1

            if limit == boundary_iterations:
                child = cp.copy(cross[index])
        tries_mutation_list[iteration][gen][index] = limit
        mutation_crossover[index] = cp.copy(child)
        print("tries",tries_mutation_list[iteration][gen][index])
    return mutation_crossover

# %% [markdown]
# ## Beispiel

# %%
#  Population
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()

example_fitness_list = np.array([0, 0, 0])
example_counter = 0
for example_chromosome in example_population:
    example_fitness_list[example_counter] = calculate_fitness(example_chromosome)
    example_counter += 1

print("Example population:", example_population)
print("Example fitness:", example_fitness_list)

#  Eltern
seed_number = 1
np.random.seed(seed_number)
example_parents = select_parents(example_fitness_list, number_parents, example_population)
print ("Select", number_parents, "parents.","Example parents:", example_parents)

#  Kreuzung
example_crossover = cross_parents_uniform(example_parents, 100, 0, 0)
print("Parents:", example_parents)
for crossed in example_crossover:
    print("Crossover:", crossed)

#  Mutation
example_mutation = mutate_crossover(example_crossover, 1000, 0, 0)
for mutated in example_mutation:
    print("Mutation:", mutated)
# Out:
# Example population: [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Example fitness: [104   0  95]
# Find interval of 38
# Find interval of 13
# Select 2 parents. Example parents: [[10 24  8  8]
#  [25  9 10  5]]
# Parents: [[10 24  8  8]
#  [25  9 10  5]]
# Crossover: [25  9  8  8]
# tries 1.0
# Mutation: [25  9  8  7]

# %% [markdown]
# # 8. Population

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `update_population(par, cross)` generiert eine neue Population, basierend auf den übergebenen Eltern `par` und den Nachfolgern `cross`.

# %%
def update_population(par, cross):
    population_update = np.concatenate((par, cross))
    return population_update

# %% [markdown]
# ## Beispiel

# %%
#  Population
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()

example_fitness_list = np.array([0, 0, 0])
example_counter = 0
for example_chromosome in example_population:
    example_fitness_list[example_counter] = calculate_fitness(example_chromosome)
    example_counter += 1

print("Example population:", example_population)
print("Example fitness:", example_fitness_list)

#  Eltern
seed_number = 1
np.random.seed(seed_number)
example_parents = select_parents(example_fitness_list, number_parents, example_population)
print ("Select", number_parents, "parents.","Example parents:", example_parents)

#  Kreuzung
example_crossover = cross_parents_uniform(example_parents, 100, 0, 0)
print("Parents:", example_parents)
for crossed in example_crossover:
    print("Crossover:", crossed)

#  Mutation
example_mutation = mutate_crossover(example_crossover, 1000, 0, 0)
for mutated in example_mutation:
    print("Mutation:", mutated)

#  Neue Population
example_population_updated = update_population(example_parents, example_mutation)
print("New population:", example_population_updated)
# Out:
# Example population: [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Example fitness: [104   0  95]
# Find interval of 38
# Find interval of 13
# Select 2 parents. Example parents: [[10 24  8  8]
#  [25  9 10  5]]
# Parents: [[10 24  8  8]
#  [25  9 10  5]]
# Crossover: [25  9  8  8]
# tries 1.0
# Mutation: [25  9  8  7]
# New population: [[10 24  8  8]
#  [25  9 10  5]
#  [25  9  8  7]]

# %% [markdown]
# # 9. Algorithmus

# %% [markdown]
# ## Funktionen

# %% [markdown]
# Die Funktion `main_part(gen, pop)` fügt alle beschriebenen Kapitel zusammen und repräsentiert den genetischen Algorithmus. Die einzelnen Schritte und deren Teilschritte sind nummeriert und im Code entsprechend markiert.
#
# Der Algorithmus folgt diesen Schritten:
#
# 1.   Generieren einer zufälligen Population
#
# Fall 1a tritt ein, wenn bereits eine Generation berechnet wurde und die End-Population für die nächste Generation als Ausgangspopulation ausgewählt wird. Der Fall 1b tritt bei der ersten Generation einer Iteration ein.
#
# 2.   Berechnen der Fitness-Werte der aktuellen Generation
#
# Der Algorithmus berechnet die Fitness-Werte und überprüft bei 2a, ob die Population Chromosome mit positiven Fitness-Werten enthält. Liegt dies nicht vor, wird solange eine neue zufällige Population generiert, bis die Bedingung erfüllt wird. Dieser Fall ist am Anfang einer Iteration relevant.
#
# 3.   Selektion der Eltern
# 4.   Kreuzung der Eltern
# 5.   Mutation der Kreuzungen
# 6.   Zusammenfügen der Eltern und der Nachfolger
# 7.   Berechnen der Fitness-Werte der neuen Generation
# 8.   Speichern von relevanten Daten zur Darstellung derer Verläufe
#
# Zu diesen Daten gehören die Kosten eines Chromosoms (8a), die Summe der Kosten einer Generation (8b), die Summe der Fitness-Werte einer Generation (8c), das beste Chromosom einer Generation (8d), die Kosten des besten Chromosoms einer Generation (8e) und das beste Chromosom einer Iteration (8f).

# %%
def main_part(gen, pop):
    #  Durchgehen jeder Iteration
    for iteration in range(number_iterations):
        #  Option, für jede Iteration eine andere zufällige Population zu verwenden
        if number_iterations <= 1:
            np.random.seed(seed_number)
        else:
            np.random.seed(iteration)
        #  Durchgehen der Generationen
        for generation in range(gen):
            print("Iteration:", iteration, "Generation:", generation)
            #  1.Ausgangspopulation
            if generation >= 1:
                #  1a.Ausgangs-Population für diese Generation ist die End-Population der vorherigen Generation
                population_before[iteration][generation] = population_after[iteration][generation - 1].copy()
            else:
                #  1b.Ausgangs-Population
                population_before[iteration][generation] = pop.copy()

            #  2.Berechnen der Fitness-Werte der Ausgangs-Population
            index_counter = 0
            for chromosome_before in population_before[iteration][generation]:
                population_fitness_before[iteration][generation][index_counter] = calculate_fitness(
                    chromosome_before)
                index_counter += 1

            #  2.a Prüfen, ob zufällige Ausgangs-Population positive Fitness-Werte enthält
            #  Dieser Fall tritt nur zu Beginn einer Iteration auf. Die Population wird neu generiert.
            while sum(population_fitness_before[iteration][generation]) <= 0:
                print("All fitnesses are negative. Change start population")
                index_counter = 0
                population_before[iteration][generation] = random_population()
                for chromosome_befores in population_before[iteration][generation]:
                    population_fitness_before[iteration][generation][index_counter] = calculate_fitness(
                        chromosome_befores)
                    index_counter += 1
            print("Population before generation:\n", population_before[iteration][generation])
            print("Fitness before generation:\n", population_fitness_before[iteration][generation])

            #  3. Selektion der Eltern
            parents_list[iteration][generation] = select_parents(
                population_fitness_before[iteration][generation], number_parents,
                population_before[iteration][generation])
            print("Parents:\n", parents_list[iteration][generation])

            #  4. Kreuzung der Eltern
            crossover_list[iteration][generation] = cross_parents_uniform(parents_list[iteration][generation],
                                                                          100, generation, iteration)
            print("Crossover and tries to cross:\n", crossover_list[iteration][generation],
                  tries_crossover_list[iteration][generation])

            #  5. Mutation der Nachfolger
            mutation_list[iteration][generation] = mutate_crossover(crossover_list[iteration][generation], 1000,
                                                                    generation, iteration)
            print("Mutation and tries to mutate:\n", mutation_list[iteration][generation],
                  tries_mutation_list[iteration][generation])

            #  6. Zusammenfügen der Eltern und der Nachfolger
            population_after[iteration][generation] = update_population(parents_list[iteration][generation],
                                                                        mutation_list[iteration][generation])
            print("Population after generation:\n", population_after[iteration][generation])

            #  7. Berechnung der Fitness-Werte
            #  8. Weiterhin werden die einzelnen Kosten der Chromosome für eine spätere Darstellung gespeichert
            index_counter = 0
            for chromosome_after in population_after[iteration][generation]:
                population_fitness_after[iteration][generation][index_counter] = calculate_fitness(
                    chromosome_after)
                #  8a. Speichern der einzelnen Kosten
                costs_list[iteration][generation][index_counter][0] = calculate_holding_cost(chromosome_after)
                costs_list[iteration][generation][index_counter][1] = calculate_purchase_cost(chromosome_after)
                costs_list[iteration][generation][index_counter][2] = calculate_transaction_cost(chromosome_after)
                costs_list[iteration][generation][index_counter][3] = calculate_total_revenue()
                index_counter += 1
            print("Fitness after generation:\n", population_fitness_after[iteration][generation])

            #  8b. Summe der Kosten einer Generation
            costs_sum_list[iteration][generation] = costs_list[iteration][generation].sum(axis=0)
            #  8c. Summe der Fitness-Werte am Ende einer Generation
            population_fitness_after_sum[iteration][generation] = np.sum(population_fitness_after[iteration][generation])
            #  8d. Ermitteln des besten Chromosoms und deren Fitness einer Generation
            index_best_chromosome_generation = np.argmax(population_fitness_after[iteration][generation])
            best_chromosomes_after[iteration][generation] = population_after[iteration][generation][index_best_chromosome_generation]
            best_fitness_after[iteration][generation] = np.amax(population_fitness_after[iteration][generation])

            #  8e. Ermitteln der einzelnen Kosten des besten Chromosoms einer Generation
            costs_max_list[iteration][generation][0] = calculate_holding_cost(best_chromosomes_after[iteration][generation])
            costs_max_list[iteration][generation][1] = calculate_purchase_cost(best_chromosomes_after[iteration][generation])
            costs_max_list[iteration][generation][2] = calculate_transaction_cost(best_chromosomes_after[iteration][generation])
            costs_max_list[iteration][generation][3] = calculate_total_revenue()

            #  8f. Ermitteln des besten Chromosoms der Iteration
            if best_fitness_after[iteration][generation] > best_fitness_of_iteration[iteration]:
                best_fitness_of_iteration[iteration] = best_fitness_after[iteration][generation]
                best_chromosome_of_iteration[iteration] = best_chromosomes_after[iteration][generation]
        # best_chromosome_of_iteration[iteration] = best_chromosomes_after[iteration][number_generations - 1]

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Die Evaluation in der Arbeit basiert auf der Population, welche mit Seed-Nummer 3 gebildet und mit Seed-Nummer 1 ausgeführt wird.

# %%
#  Initialisierung
#  Werte, die verändert werden können
seed_number = 3
np.random.seed(seed_number)
selling_price = np.array([13, 9])  # Verkaufspreise der Produkte: P1 kostet 13, P2 9 Einheiten
supplier_price = np.array([[6, 4], [4, 3]])  # Lieferantenpreise der Produkte: [6, 4] bedeutet, dass P1 von L1 6 Einheiten kostet und P2 von L1 4 Einheiten kostet
transaction_cost = np.array([10, 30])  # Transaktionkosten der Lieferanten: L1 kostet 10, L2 30 Einheiten
holding_cost = np.array([30, 20])  # Lagerkosten für die Produkte: P1 kostet 30, P2 20 Einheiten
demands = np.array([30, 14])  # Nachfrage der Produkte: Nachfrage für P1 ist 30, für P2 14 Einheiten
number_products = len(selling_price)  # Anzahl an Produkten, abhängig von selling_price
number_suppliers = len(supplier_price)  # Anzahl an Lieferanten, abhängig von supplier_price
population_size = 3  # Populationsgröße
lower_bound = 0  # Untere Grenze für Werte zur Mutation
upper_bound = np.array([50, 34])  # Obere Grenze für Werte zur Mutation des jeweiligen Produktes: ein Gen von P1 kann bei der Mutation maximal den Wert 50 annehmen
number_iterations = 1  # Anzahl an Iterationen
number_generations = 15  # Anzahl an Generationen
penalty = 99999  # Strafe, wenn Chromosom nicht Anforderungen erfüllt

chromosome_size = number_suppliers * number_products  # Chromosomgröße
init_population = np.zeros((population_size, chromosome_size))  # Ausgangspopulation, zunächst nur aus Chromosomen mit 0 als Genen
number_parents = (population_size // 2) + (population_size % 2)  # Anzahl der Eltern, abhängig von der Populationsgröße
number_children = (population_size - number_parents)  # Anzahl der Nachfolgerm, abhängig von der Populationsgröße

#  Variablen zum Speichern und Analysieren
population_before = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Anfang einer Generation
population_fitness_before = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Anfang einer Generation
population_after = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Ende einer Generation
population_fitness_after = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Ende einer Generation
population_fitness_after_sum = np.zeros((number_iterations, number_generations))  # alle Summen der Fitness-Werte jeder Population am Ende einer Generation
best_chromosomes_after = np.zeros((number_iterations, number_generations, chromosome_size))  # alle besten Chromosome jeder Generation
best_fitness_after = np.zeros((number_iterations, number_generations))  # alle Fitness-Werte der besten Chromosome jeder Generation
best_chromosome_of_iteration = np.zeros((number_iterations, chromosome_size))  # besten Chromosome jeder Iteration
best_fitness_of_iteration = np.zeros(number_iterations)  # bester Fitness-Wert jeder Iteration

parents_list = np.zeros((number_iterations, number_generations, number_parents, chromosome_size))  # Liste aller Eltern
crossover_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Kreuzungen
tries_crossover_list = np.zeros((number_iterations, number_generations, number_children))  # Liste aller Versuchsanzahlen zur Kreuzung
mutation_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Mutationen
tries_mutation_list = np.zeros((number_iterations, number_generations, number_children))  # Lister aller Versuchsanzahlen zur Mutation

costs_list = np.zeros((number_iterations, number_generations, population_size, 4))  # Liste der einzelnen Kosten jeder Population
costs_max_list = np.zeros((number_iterations, number_generations, 4))  # Liste der einzelnen Kosten der besten Chromosome jeder Generation
costs_sum_list = np.zeros((number_iterations, number_generations, 4))  # Liste der Summe der Kosten jeder Generation

# Population
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()
print("Population at the beginning", example_population)

# Hauptteil
seed_number = 1
np.random.seed(seed_number)
start_time = time.time()
main_part(number_generations, example_population)
end_time = time.time()
print("The algorithm takes", "{:.2f}".format(end_time - start_time), "seconds for process")
print("The chromosome", best_chromosome_of_iteration, "has the maximum fitness of", best_fitness_of_iteration)
# Out:
# Population at the beginning [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Iteration: 0 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 38
# Find interval of 13
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  8.]] [2.]
# tries 1.0
# Mutation and tries to mutate:
#  [[25.  9.  8.  7.]] [1.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [25.  9.  8.  7.]]
# Fitness after generation:
#  [104.  95.  97.]
# Iteration: 0 Generation: 1
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [25.  9.  8.  7.]]
# Fitness before generation:
#  [104.  95.  97.]
# Find interval of 238
# Find interval of 135
# Parents:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  7.]] [1.]
# tries 6.0
# Mutation and tries to mutate:
#  [[25.  9.  7.  7.]] [6.]
# Population after generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]
#  [25.  9.  7.  7.]]
# Fitness after generation:
#  [ 97.  95. 121.]
# Iteration: 0 Generation: 2
# Population before generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]
#  [25.  9.  7.  7.]]
# Fitness before generation:
#  [ 97.  95. 121.]
# Find interval of 23
# Find interval of 58
# Parents:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  5.]] [2.]
# tries 8.0
# Mutation and tries to mutate:
#  [[25.  9. 10.  4.]] [8.]
# Population after generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]
#  [25.  9. 10.  4.]]
# Fitness after generation:
#  [ 97.  95. 118.]
# Iteration: 0 Generation: 3
# Population before generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  5.]
#  [25.  9. 10.  4.]]
# Fitness before generation:
#  [ 97.  95. 118.]
# Find interval of 26
# Find interval of 112
# Parents:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  7.]] [1.]
# tries 16.0
# Mutation and tries to mutate:
#  [[25.  9.  8.  7.]] [16.]
# Population after generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  9.  8.  7.]]
# Fitness after generation:
#  [ 97. 118.  97.]
# Iteration: 0 Generation: 4
# Population before generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  9.  8.  7.]]
# Fitness before generation:
#  [ 97. 118.  97.]
# Find interval of 76
# Find interval of 77
# Parents:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  7.]] [1.]
# tries 13.0
# Mutation and tries to mutate:
#  [[25.  6.  8.  7.]] [13.]
# Population after generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  6.  8.  7.]]
# Fitness after generation:
#  [ 97. 118. 199.]
# Iteration: 0 Generation: 5
# Population before generation:
#  [[25.  9.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  6.  8.  7.]]
# Fitness before generation:
#  [ 97. 118. 199.]
# Find interval of 195
# Find interval of 177
# Parents:
#  [[25.  9. 10.  4.]
#  [25.  6.  8.  7.]]
# Crossover and tries to cross:
#  [[25.  6.  8.  7.]] [1.]
# tries 70.0
# Mutation and tries to mutate:
#  [[25.  5.  8.  7.]] [70.]
# Population after generation:
#  [[25.  9. 10.  4.]
#  [25.  6.  8.  7.]
#  [25.  5.  8.  7.]]
# Fitness after generation:
#  [118. 199. 233.]
# Iteration: 0 Generation: 6
# Population before generation:
#  [[25.  9. 10.  4.]
#  [25.  6.  8.  7.]
#  [25.  5.  8.  7.]]
# Fitness before generation:
#  [118. 199. 233.]
# Find interval of 309
# Find interval of 90
# Parents:
#  [[25.  6.  8.  7.]
#  [25.  9. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  7.]] [1.]
# tries 42.0
# Mutation and tries to mutate:
#  [[25.  8. 10.  7.]] [42.]
# Population after generation:
#  [[25.  6.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  8. 10.  7.]]
# Fitness after generation:
#  [199. 118.  83.]
# Iteration: 0 Generation: 7
# Population before generation:
#  [[25.  6.  8.  7.]
#  [25.  9. 10.  4.]
#  [25.  8. 10.  7.]]
# Fitness before generation:
#  [199. 118.  83.]
# Find interval of 169
# Find interval of 177
# Parents:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  7.]]
# Crossover and tries to cross:
#  [[25.  8.  8.  7.]] [1.]
# tries 98.0
# Mutation and tries to mutate:
#  [[24.  8.  8.  7.]] [98.]
# Population after generation:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  7.]
#  [24.  8.  8.  7.]]
# Fitness after generation:
#  [199.  83. 167.]
# Iteration: 0 Generation: 8
# Population before generation:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  7.]
#  [24.  8.  8.  7.]]
# Fitness before generation:
#  [199.  83. 167.]
# Find interval of 278
# Find interval of 47
# Parents:
#  [[25.  8. 10.  7.]
#  [25.  6.  8.  7.]]
# Crossover and tries to cross:
#  [[25.  8. 10.  7.]] [1.]
# tries 14.0
# Mutation and tries to mutate:
#  [[25.  8. 10.  4.]] [14.]
# Population after generation:
#  [[25.  8. 10.  7.]
#  [25.  6.  8.  7.]
#  [25.  8. 10.  4.]]
# Fitness after generation:
#  [ 83. 199. 152.]
# Iteration: 0 Generation: 9
# Population before generation:
#  [[25.  8. 10.  7.]
#  [25.  6.  8.  7.]
#  [25.  8. 10.  4.]]
# Fitness before generation:
#  [ 83. 199. 152.]
# Find interval of 266
# Find interval of 125
# Parents:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  6. 10.  4.]] [1.]
# tries 55.0
# Mutation and tries to mutate:
#  [[25.  5. 10.  4.]] [55.]
# Population after generation:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  4.]
#  [25.  5. 10.  4.]]
# Fitness after generation:
#  [199. 152. 254.]
# Iteration: 0 Generation: 10
# Population before generation:
#  [[25.  6.  8.  7.]
#  [25.  8. 10.  4.]
#  [25.  5. 10.  4.]]
# Fitness before generation:
#  [199. 152. 254.]
# Find interval of 534
# Find interval of 118
# Parents:
#  [[25.  5. 10.  4.]
#  [25.  6.  8.  7.]]
# Crossover and tries to cross:
#  [[25.  6.  8.  7.]] [2.]
# tries 29.0
# Mutation and tries to mutate:
#  [[25.  6.  7.  7.]] [29.]
# Population after generation:
#  [[25.  5. 10.  4.]
#  [25.  6.  8.  7.]
#  [25.  6.  7.  7.]]
# Fitness after generation:
#  [254. 199. 223.]
# Iteration: 0 Generation: 11
# Population before generation:
#  [[25.  5. 10.  4.]
#  [25.  6.  8.  7.]
#  [25.  6.  7.  7.]]
# Fitness before generation:
#  [254. 199. 223.]
# Find interval of 18
# Find interval of 243
# Parents:
#  [[25.  5. 10.  4.]
#  [25.  6.  7.  7.]]
# Crossover and tries to cross:
#  [[25.  6. 10.  7.]] [1.]
# tries 37.0
# Mutation and tries to mutate:
#  [[25.  6. 10.  5.]] [37.]
# Population after generation:
#  [[25.  5. 10.  4.]
#  [25.  6.  7.  7.]
#  [25.  6. 10.  5.]]
# Fitness after generation:
#  [254. 223. 197.]
# Iteration: 0 Generation: 12
# Population before generation:
#  [[25.  5. 10.  4.]
#  [25.  6.  7.  7.]
#  [25.  6. 10.  5.]]
# Fitness before generation:
#  [254. 223. 197.]
# Find interval of 544
# Find interval of 60
# Parents:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  5. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5. 10.  4.]] [1000.]
# Population after generation:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]
#  [25.  5. 10.  4.]]
# Fitness after generation:
#  [197. 254. 254.]
# Iteration: 0 Generation: 13
# Population before generation:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]
#  [25.  5. 10.  4.]]
# Fitness before generation:
#  [197. 254. 254.]
# Find interval of 71
# Find interval of 260
# Parents:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  6. 10.  4.]] [1.]
# tries 240.0
# Mutation and tries to mutate:
#  [[24.  6. 10.  4.]] [240.]
# Population after generation:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]
#  [24.  6. 10.  4.]]
# Fitness after generation:
#  [197. 254. 256.]
# Iteration: 0 Generation: 14
# Population before generation:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]
#  [24.  6. 10.  4.]]
# Fitness before generation:
#  [197. 254. 256.]
# Find interval of 32
# Find interval of 84
# Parents:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]]
# Crossover and tries to cross:
#  [[25.  5. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5. 10.  4.]] [1000.]
# Population after generation:
#  [[25.  6. 10.  5.]
#  [25.  5. 10.  4.]
#  [25.  5. 10.  4.]]
# Fitness after generation:
#  [197. 254. 254.]
# The algorithm takes 0.53 seconds for process
# The chromosome [[24.  6. 10.  4.]] has the maximum fitness of [256.]

# %% [markdown]
# ## Plot

# %% [markdown]
# Die Funktion `plot()` ist notwendig zur Darstellung von Daten.

# %%
def plot(data, title, x, y):
    plt.plot(data)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    plt.show()

# %% [markdown]
# `single_plot()` zeigt alle relevanten Datenverläufe an, wenn nur eine Iteration ausgeführt wird.

# %%
def single_plot():
    plot(best_fitness_after[number_iterations - 1], "Best fitness value of each generation", "Generations", "Fitness")
    plot(population_fitness_after_sum[number_iterations - 1], "Sum of fitness-values of each generation", "Generations", "Fitness")
    plot(costs_max_list[number_iterations - 1], "Costs of best chromosomes", "Generations", "Costs")
    plot(costs_sum_list[number_iterations - 1], "Sum of costs of each generation", "Generations", "Costs")
    plot(tries_crossover_list[number_iterations - 1], "Tries of each generation to cross", "Generations", "Tries")
    plot(tries_mutation_list[number_iterations - 1], "Tries of each generation to mutate", "Generations", "Tries")

# %% [markdown]
# Der folgende Abschnitt zeigt die Daten des vorherigen Beispiels an. Die erste Grafik stellt den Verlauf der besten Chromosome jeder Generation dar. Die zweite Darstellung präsentiert die Summe der Fitness-Werte jeder Generation. Anschließend folgt die Veranschaulichung der einzelnen Kostenverläufe, bezogen auf das beste Chromosom und die Summe der Chromosome. Die letzten zwei Abbildungen zeigen, wie viele Versuche notwendig sind, um zwei Eltern zu kreuzen und den Nachfolger zu mutieren.

# %%
single_plot()

# %% [markdown]
# # 10. Mehrfache Ausführung

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Dieses Beispiel führt den Algorithmus ausgehend von der selben Population mehrmals aus. Die Variable `number_iterations` speichert die Anzahl an Iterationen.

# %%
#  Initialisierung
#  Werte, die verändert werden können
seed_number = 3
np.random.seed(seed_number)
selling_price = np.array([13, 9])  # Verkaufspreise der Produkte: P1 kostet 13, P2 9 Einheiten
supplier_price = np.array([[6, 4], [4, 3]])  # Lieferantenpreise der Produkte: [6, 4] bedeutet, dass P1 von L1 6 Einheiten kostet und P2 von L1 4 Einheiten kostet
transaction_cost = np.array([10, 30])  # Transaktionkosten der Lieferanten: L1 kostet 10, L2 30 Einheiten
holding_cost = np.array([30, 20])  # Lagerkosten für die Produkte: P1 kostet 30, P2 20 Einheiten
demands = np.array([30, 14])  # Nachfrage der Produkte: Nachfrage für P1 ist 30, für P2 14 Einheiten
number_products = len(selling_price)  # Anzahl an Produkten, abhängig von selling_price
number_suppliers = len(supplier_price)  # Anzahl an Lieferanten, abhängig von supplier_price
population_size = 3  # Populationsgröße
lower_bound = 0  # Untere Grenze für Werte zur Mutation
upper_bound = np.array([50, 34])  # Obere Grenze für Werte zur Mutation des jeweiligen Produktes: ein Gen von P1 kann bei der Mutation maximal den Wert 50 annehmen
number_iterations = 100  # Anzahl an Iterationen
number_generations = 15  # Anzahl an Generationen
penalty = 99999  # Strafe, wenn Chromosom nicht Anforderungen erfüllt

chromosome_size = number_suppliers * number_products  # Chromosomgröße
init_population = np.zeros((population_size, chromosome_size))  # Ausgangspopulation, zunächst nur aus Chromosomen mit 0 als Genen
number_parents = (population_size // 2) + (population_size % 2)  # Anzahl der Eltern, abhängig von der Populationsgröße
number_children = (population_size - number_parents)  # Anzahl der Nachfolgerm, abhängig von der Populationsgröße

#  Variablen zum Speichern und Analysieren
population_before = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Anfang einer Generation
population_fitness_before = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Anfang einer Generation
population_after = np.zeros((number_iterations, number_generations, population_size, chromosome_size))  # alle Populationen am Ende einer Generation
population_fitness_after = np.zeros((number_iterations, number_generations, population_size))  # alle Fitness-Werte jeder Population am Ende einer Generation
population_fitness_after_sum = np.zeros((number_iterations, number_generations))  # alle Summen der Fitness-Werte jeder Population am Ende einer Generation
best_chromosomes_after = np.zeros((number_iterations, number_generations, chromosome_size))  # alle besten Chromosome jeder Generation
best_fitness_after = np.zeros((number_iterations, number_generations))  # alle Fitness-Werte der besten Chromosome jeder Generation
best_chromosome_of_iteration = np.zeros((number_iterations, chromosome_size))  # besten Chromosome jeder Iteration
best_fitness_of_iteration = np.zeros(number_iterations)  # bester Fitness-Wert jeder Iteration

parents_list = np.zeros((number_iterations, number_generations, number_parents, chromosome_size))  # Liste aller Eltern
crossover_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Kreuzungen
tries_crossover_list = np.zeros((number_iterations, number_generations, number_children))  # Liste aller Versuchsanzahlen zur Kreuzung
mutation_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))  # Liste aller Mutationen
tries_mutation_list = np.zeros((number_iterations, number_generations, number_children))  # Lister aller Versuchsanzahlen zur Mutation

costs_list = np.zeros((number_iterations, number_generations, population_size, 4))  # Liste der einzelnen Kosten jeder Population
costs_max_list = np.zeros((number_iterations, number_generations, 4))  # Liste der einzelnen Kosten der besten Chromosome jeder Generation
costs_sum_list = np.zeros((number_iterations, number_generations, 4))  # Liste der Summe der Kosten jeder Generation

# Population und Hauptteil
seed_number = 3
np.random.seed(seed_number)
example_population = random_population()
seed_number = 1
np.random.seed(seed_number)
start_time = time.time()
main_part(number_generations, example_population)
end_time = time.time()
print("The algorithm takes", "{:.2f}".format(end_time - start_time), "seconds for process")
print("The chromosome", best_chromosome_of_iteration[np.argmax(best_fitness_of_iteration)],
          "has the maximum fitness of", np.amax(best_fitness_of_iteration))
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#  [[ 8. 22.  8.  8.]] [13.]
# Population after generation:
#  [[ 8. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 8. 22.  8.  8.]]
# Fitness after generation:
#  [176. 176. 244.]
# Iteration: 85 Generation: 8
# Population before generation:
#  [[ 8. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 8. 22.  8.  8.]]
# Fitness before generation:
#  [176. 176. 244.]
# Find interval of 71
# Find interval of 144
# Parents:
#  [[ 8. 24.  8.  8.]
#  [ 8. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 8. 24.  8.  8.]] [1.]
# tries 6.0
# Mutation and tries to mutate:
#  [[ 8. 23.  8.  8.]] [6.]
# Population after generation:
#  [[ 8. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 8. 23.  8.  8.]]
# Fitness after generation:
#  [176. 176. 210.]
# Iteration: 85 Generation: 9
# Population before generation:
#  [[ 8. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 8. 23.  8.  8.]]
# Fitness before generation:
#  [176. 176. 210.]
# Find interval of 523
# Find interval of 88
# Parents:
#  [[ 8. 23.  8.  8.]
#  [ 8. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 8. 24.  8.  8.]] [1.]
# tries 62.0
# Mutation and tries to mutate:
#  [[ 7. 24.  8.  8.]] [62.]
# Population after generation:
#  [[ 8. 23.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 7. 24.  8.  8.]]
# Fitness after generation:
#  [210. 176. 212.]
# Iteration: 85 Generation: 10
# Population before generation:
#  [[ 8. 23.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 7. 24.  8.  8.]]
# Fitness before generation:
#  [210. 176. 212.]
# Find interval of 358
# Find interval of 384
# Parents:
#  [[ 8. 24.  8.  8.]
#  [ 7. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  8.  8.]] [1.]
# tries 19.0
# Mutation and tries to mutate:
#  [[ 6. 24.  8.  8.]] [19.]
# Population after generation:
#  [[ 8. 24.  8.  8.]
#  [ 7. 24.  8.  8.]
#  [ 6. 24.  8.  8.]]
# Fitness after generation:
#  [176. 212. 248.]
# Iteration: 85 Generation: 11
# Population before generation:
#  [[ 8. 24.  8.  8.]
#  [ 7. 24.  8.  8.]
#  [ 6. 24.  8.  8.]]
# Fitness before generation:
#  [176. 212. 248.]
# Find interval of 571
# Find interval of 66
# Parents:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 6. 24.  8.  8.]] [1.]
# tries 123.0
# Mutation and tries to mutate:
#  [[ 6. 24.  8.  7.]] [123.]
# Population after generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  8.  7.]]
# Fitness after generation:
#  [248. 176. 271.]
# Iteration: 85 Generation: 12
# Population before generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  8.  7.]]
# Fitness before generation:
#  [248. 176. 271.]
# Find interval of 58
# Find interval of 61
# Parents:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 8. 24.  8.  8.]] [1.]
# tries 26.0
# Mutation and tries to mutate:
#  [[ 6. 24.  8.  8.]] [26.]
# Population after generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  8.  8.]]
# Fitness after generation:
#  [248. 176. 248.]
# Iteration: 85 Generation: 13
# Population before generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  8.  8.]]
# Fitness before generation:
#  [248. 176. 248.]
# Find interval of 196
# Find interval of 96
# Parents:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 6. 24.  8.  8.]] [1.]
# tries 86.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [86.]
# Population after generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [248. 176. 296.]
# Iteration: 85 Generation: 14
# Population before generation:
#  [[ 6. 24.  8.  8.]
#  [ 8. 24.  8.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness before generation:
#  [248. 176. 296.]
# Find interval of 718
# Find interval of 128
# Parents:
#  [[ 6. 24.  6.  8.]
#  [ 6. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 6. 24.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [1000.]
# Population after generation:
#  [[ 6. 24.  6.  8.]
#  [ 6. 24.  8.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [296. 248. 296.]
# Iteration: 86 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 149
# Find interval of 97
# Parents:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  5.]] [6.]
# tries 38.0
# Mutation and tries to mutate:
#  [[25.  9. 10.  4.]] [38.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [25.  9. 10.  4.]]
# Fitness after generation:
#  [ 95. 104. 118.]
# Iteration: 86 Generation: 1
# Population before generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [25.  9. 10.  4.]]
# Fitness before generation:
#  [ 95. 104. 118.]
# Find interval of 187
# Find interval of 87
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [4.]
# tries 2.0
# Mutation and tries to mutate:
#  [[ 9. 24.  8.  8.]] [2.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [ 9. 24.  8.  8.]]
# Fitness after generation:
#  [104.  95. 140.]
# Iteration: 86 Generation: 2
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [ 9. 24.  8.  8.]]
# Fitness before generation:
#  [104.  95. 140.]
# Find interval of 55
# Find interval of 63
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  8.]] [1.]
# tries 2.0
# Mutation and tries to mutate:
#  [[10. 24. 10.  7.]] [2.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24. 10.  7.]]
# Fitness after generation:
#  [104.  95.  79.]
# Iteration: 86 Generation: 3
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24. 10.  7.]]
# Fitness before generation:
#  [104.  95.  79.]
# Find interval of 36
# Find interval of 68
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  5.]] [2.]
# tries 46.0
# Mutation and tries to mutate:
#  [[10. 24.  9.  5.]] [46.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24.  9.  5.]]
# Fitness after generation:
#  [104.  95. 149.]
# Iteration: 86 Generation: 4
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24.  9.  5.]]
# Fitness before generation:
#  [104.  95. 149.]
# Find interval of 32
# Find interval of 154
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 24.  9.  5.]]
# Crossover and tries to cross:
#  [[10. 24.  9.  8.]] [1.]
# tries 10.0
# Mutation and tries to mutate:
#  [[ 7. 24.  9.  8.]] [10.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  9.  5.]
#  [ 7. 24.  9.  8.]]
# Fitness after generation:
#  [104. 149. 188.]
# Iteration: 86 Generation: 5
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  9.  5.]
#  [ 7. 24.  9.  8.]]
# Fitness before generation:
#  [104. 149. 188.]
# Find interval of 117
# Find interval of 75
# Parents:
#  [[10. 24.  9.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  9.  8.]] [1.]
# tries 6.0
# Mutation and tries to mutate:
#  [[ 7. 24.  9.  8.]] [6.]
# Population after generation:
#  [[10. 24.  9.  5.]
#  [10. 24.  8.  8.]
#  [ 7. 24.  9.  8.]]
# Fitness after generation:
#  [149. 104. 188.]
# Iteration: 86 Generation: 6
# Population before generation:
#  [[10. 24.  9.  5.]
#  [10. 24.  8.  8.]
#  [ 7. 24.  9.  8.]]
# Fitness before generation:
#  [149. 104. 188.]
# Find interval of 417
# Find interval of 189
# Parents:
#  [[ 7. 24.  9.  8.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  8.  8.]] [1.]
# tries 47.0
# Mutation and tries to mutate:
#  [[ 7. 24.  6.  8.]] [47.]
# Population after generation:
#  [[ 7. 24.  9.  8.]
#  [10. 24.  8.  8.]
#  [ 7. 24.  6.  8.]]
# Fitness after generation:
#  [188. 104. 260.]
# Iteration: 86 Generation: 7
# Population before generation:
#  [[ 7. 24.  9.  8.]
#  [10. 24.  8.  8.]
#  [ 7. 24.  6.  8.]]
# Fitness before generation:
#  [188. 104. 260.]
# Find interval of 490
# Find interval of 159
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 24.  9.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 311.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [311.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 24.  9.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [260. 188. 294.]
# Iteration: 86 Generation: 8
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 24.  9.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [260. 188. 294.]
# Find interval of 539
# Find interval of 47
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 209.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [209.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [294. 260. 296.]
# Iteration: 86 Generation: 9
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness before generation:
#  [294. 260. 296.]
# Find interval of 232
# Find interval of 86
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 23.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 260. 294.]
# Iteration: 86 Generation: 10
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 260. 294.]
# Find interval of 567
# Find interval of 215
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 23.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 260. 294.]
# Iteration: 86 Generation: 11
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 260. 294.]
# Find interval of 346
# Find interval of 437
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 2.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [2.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [260. 294. 296.]
# Iteration: 86 Generation: 12
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness before generation:
#  [260. 294. 296.]
# Find interval of 759
# Find interval of 385
# Parents:
#  [[ 6. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 6. 24.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [1000.]
# Population after generation:
#  [[ 6. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [296. 294. 296.]
# Iteration: 86 Generation: 13
# Population before generation:
#  [[ 6. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness before generation:
#  [296. 294. 296.]
# Find interval of 552
# Find interval of 40
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 68.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [68.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 296. 294.]
# Iteration: 86 Generation: 14
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 296. 294.]
# Find interval of 687
# Find interval of 210
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 6. 24.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [294. 296. 296.]
# Iteration: 87 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 78
# Find interval of 60
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  8.]] [1.]
# tries 18.0
# Mutation and tries to mutate:
#  [[25.  9.  6.  8.]] [18.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [25.  9.  6.  8.]]
# Fitness after generation:
#  [104.  95. 122.]
# Iteration: 87 Generation: 1
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [25.  9.  6.  8.]]
# Fitness before generation:
#  [104.  95. 122.]
# Find interval of 31
# Find interval of 215
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [4.]
# tries 47.0
# Mutation and tries to mutate:
#  [[10. 22.  8.  8.]] [47.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]
#  [10. 22.  8.  8.]]
# Fitness after generation:
#  [104. 122. 172.]
# Iteration: 87 Generation: 2
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]
#  [10. 22.  8.  8.]]
# Fitness before generation:
#  [104. 122. 172.]
# Find interval of 164
# Find interval of 146
# Parents:
#  [[25.  9.  6.  8.]
#  [10. 22.  8.  8.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  8.]] [1.]
# tries 7.0
# Mutation and tries to mutate:
#  [[22.  9.  8.  8.]] [7.]
# Population after generation:
#  [[25.  9.  6.  8.]
#  [10. 22.  8.  8.]
#  [22.  9.  8.  8.]]
# Fitness after generation:
#  [122. 172. 182.]
# Iteration: 87 Generation: 3
# Population before generation:
#  [[25.  9.  6.  8.]
#  [10. 22.  8.  8.]
#  [22.  9.  8.  8.]]
# Fitness before generation:
#  [122. 172. 182.]
# Find interval of 197
# Find interval of 44
# Parents:
#  [[10. 22.  8.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  9.  8.  8.]] [1.]
# tries 8.0
# Mutation and tries to mutate:
#  [[25.  5.  8.  8.]] [8.]
# Population after generation:
#  [[10. 22.  8.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  8.  8.]]
# Fitness after generation:
#  [172. 122. 210.]
# Iteration: 87 Generation: 4
# Population before generation:
#  [[10. 22.  8.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  8.  8.]]
# Fitness before generation:
#  [172. 122. 210.]
# Find interval of 237
# Find interval of 204
# Parents:
#  [[25.  9.  6.  8.]
#  [25.  5.  8.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  8.  8.]] [1.]
# tries 8.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [8.]
# Population after generation:
#  [[25.  9.  6.  8.]
#  [25.  5.  8.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [122. 210. 258.]
# Iteration: 87 Generation: 5
# Population before generation:
#  [[25.  9.  6.  8.]
#  [25.  5.  8.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [122. 210. 258.]
# Find interval of 419
# Find interval of 114
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 122. 258.]
# Iteration: 87 Generation: 6
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 122. 258.]
# Find interval of 394
# Find interval of 52
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 122. 258.]
# Iteration: 87 Generation: 7
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 122. 258.]
# Find interval of 59
# Find interval of 300
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 8
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 27
# Find interval of 249
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 9
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 367
# Find interval of 328
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 10
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 482
# Find interval of 85
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 11
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 503
# Find interval of 215
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 12
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 42
# Find interval of 126
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 13
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 250
# Find interval of 196
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 87 Generation: 14
# Population before generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness before generation:
#  [258. 258. 258.]
# Find interval of 122
# Find interval of 342
# Parents:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  5.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  6.  8.]] [1000.]
# Population after generation:
#  [[25.  5.  6.  8.]
#  [25.  5.  6.  8.]
#  [25.  5.  6.  8.]]
# Fitness after generation:
#  [258. 258. 258.]
# Iteration: 88 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 33
# Find interval of 80
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [3.]
# tries 3.0
# Mutation and tries to mutate:
#  [[10. 24.  6.  8.]] [3.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24.  6.  8.]]
# Fitness after generation:
#  [104.  95. 152.]
# Iteration: 88 Generation: 1
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24.  6.  8.]]
# Fitness before generation:
#  [104.  95. 152.]
# Find interval of 11
# Find interval of 87
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  5.]] [1.]
# tries 19.0
# Mutation and tries to mutate:
#  [[22.  9. 10.  5.]] [19.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [22.  9. 10.  5.]]
# Fitness after generation:
#  [104.  95. 203.]
# Iteration: 88 Generation: 2
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [22.  9. 10.  5.]]
# Fitness before generation:
#  [104.  95. 203.]
# Find interval of 327
# Find interval of 126
# Parents:
#  [[22.  9. 10.  5.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  5.]] [1.]
# tries 10.0
# Mutation and tries to mutate:
#  [[22.  9.  9.  5.]] [10.]
# Population after generation:
#  [[22.  9. 10.  5.]
#  [25.  9. 10.  5.]
#  [22.  9.  9.  5.]]
# Fitness after generation:
#  [203.  95. 227.]
# Iteration: 88 Generation: 3
# Population before generation:
#  [[22.  9. 10.  5.]
#  [25.  9. 10.  5.]
#  [22.  9.  9.  5.]]
# Fitness before generation:
#  [203.  95. 227.]
# Find interval of 283
# Find interval of 420
# Parents:
#  [[25.  9. 10.  5.]
#  [22.  9.  9.  5.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  5.]] [1.]
# tries 2.0
# Mutation and tries to mutate:
#  [[22.  9. 10.  4.]] [2.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [22.  9.  9.  5.]
#  [22.  9. 10.  4.]]
# Fitness after generation:
#  [ 95. 227. 226.]
# Iteration: 88 Generation: 4
# Population before generation:
#  [[25.  9. 10.  5.]
#  [22.  9.  9.  5.]
#  [22.  9. 10.  4.]]
# Fitness before generation:
#  [ 95. 227. 226.]
# Find interval of 410
# Find interval of 254
# Parents:
#  [[22.  9. 10.  4.]
#  [22.  9.  9.  5.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  5.]] [1.]
# tries 23.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  5.]] [23.]
# Population after generation:
#  [[22.  9. 10.  4.]
#  [22.  9.  9.  5.]
#  [22.  8. 10.  5.]]
# Fitness after generation:
#  [226. 227. 237.]
# Iteration: 88 Generation: 5
# Population before generation:
#  [[22.  9. 10.  4.]
#  [22.  9.  9.  5.]
#  [22.  8. 10.  5.]]
# Fitness before generation:
#  [226. 227. 237.]
# Find interval of 60
# Find interval of 316
# Parents:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  5.]] [1.]
# tries 3.0
# Mutation and tries to mutate:
#  [[22.  9.  9.  5.]] [3.]
# Population after generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]
#  [22.  9.  9.  5.]]
# Fitness after generation:
#  [226. 237. 227.]
# Iteration: 88 Generation: 6
# Population before generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]
#  [22.  9.  9.  5.]]
# Fitness before generation:
#  [226. 237. 227.]
# Find interval of 76
# Find interval of 58
# Parents:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [226. 237. 260.]
# Iteration: 88 Generation: 7
# Population before generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  5.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [226. 237. 260.]
# Find interval of 102
# Find interval of 361
# Parents:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  4.]] [1.]
# tries 58.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [58.]
# Population after generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [226. 260. 260.]
# Iteration: 88 Generation: 8
# Population before generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [226. 260. 260.]
# Find interval of 609
# Find interval of 130
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  4.]] [1.]
# tries 240.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [240.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 226. 260.]
# Iteration: 88 Generation: 9
# Population before generation:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [260. 226. 260.]
# Find interval of 234
# Find interval of 193
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  9. 10.  4.]] [1.]
# tries 94.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [94.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 226. 260.]
# Iteration: 88 Generation: 10
# Population before generation:
#  [[22.  8. 10.  4.]
#  [22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [260. 226. 260.]
# Find interval of 459
# Find interval of 273
# Parents:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [226. 260. 260.]
# Iteration: 88 Generation: 11
# Population before generation:
#  [[22.  9. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [226. 260. 260.]
# Find interval of 435
# Find interval of 398
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 260. 260.]
# Iteration: 88 Generation: 12
# Population before generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [260. 260. 260.]
# Find interval of 251
# Find interval of 90
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 260. 260.]
# Iteration: 88 Generation: 13
# Population before generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [260. 260. 260.]
# Find interval of 662
# Find interval of 97
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 260. 260.]
# Iteration: 88 Generation: 14
# Population before generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness before generation:
#  [260. 260. 260.]
# Find interval of 515
# Find interval of 401
# Parents:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Crossover and tries to cross:
#  [[22.  8. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[22.  8. 10.  4.]] [1000.]
# Population after generation:
#  [[22.  8. 10.  4.]
#  [22.  8. 10.  4.]
#  [22.  8. 10.  4.]]
# Fitness after generation:
#  [260. 260. 260.]
# Iteration: 89 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 148
# Find interval of 31
# Parents:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  5.]] [6.]
# tries 28.0
# Mutation and tries to mutate:
#  [[ 9. 24. 10.  5.]] [28.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [ 9. 24. 10.  5.]]
# Fitness after generation:
#  [ 95. 104. 161.]
# Iteration: 89 Generation: 1
# Population before generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [ 9. 24. 10.  5.]]
# Fitness before generation:
#  [ 95. 104. 161.]
# Find interval of 317
# Find interval of 53
# Parents:
#  [[ 9. 24. 10.  5.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[ 9. 24. 10.  5.]] [1.]
# tries 33.0
# Mutation and tries to mutate:
#  [[ 9. 23. 10.  5.]] [33.]
# Population after generation:
#  [[ 9. 24. 10.  5.]
#  [25.  9. 10.  5.]
#  [ 9. 23. 10.  5.]]
# Fitness after generation:
#  [161.  95. 195.]
# Iteration: 89 Generation: 2
# Population before generation:
#  [[ 9. 24. 10.  5.]
#  [25.  9. 10.  5.]
#  [ 9. 23. 10.  5.]]
# Fitness before generation:
#  [161.  95. 195.]
# Find interval of 426
# Find interval of 158
# Parents:
#  [[ 9. 23. 10.  5.]
#  [ 9. 24. 10.  5.]]
# Crossover and tries to cross:
#  [[ 9. 23. 10.  5.]] [1.]
# tries 38.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  5.]] [38.]
# Population after generation:
#  [[ 9. 23. 10.  5.]
#  [ 9. 24. 10.  5.]
#  [ 7. 23. 10.  5.]]
# Fitness after generation:
#  [195. 161. 267.]
# Iteration: 89 Generation: 3
# Population before generation:
#  [[ 9. 23. 10.  5.]
#  [ 9. 24. 10.  5.]
#  [ 7. 23. 10.  5.]]
# Fitness before generation:
#  [195. 161. 267.]
# Find interval of 22
# Find interval of 387
# Parents:
#  [[ 9. 23. 10.  5.]
#  [ 7. 23. 10.  5.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  5.]] [1.]
# tries 27.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [27.]
# Population after generation:
#  [[ 9. 23. 10.  5.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [195. 267. 290.]
# Iteration: 89 Generation: 4
# Population before generation:
#  [[ 9. 23. 10.  5.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [195. 267. 290.]
# Find interval of 642
# Find interval of 269
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 267. 290.]
# Iteration: 89 Generation: 5
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 267. 290.]
# Find interval of 176
# Find interval of 193
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  5.]] [1.]
# tries 68.0
# Mutation and tries to mutate:
#  [[ 7. 23.  9.  5.]] [68.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23.  9.  5.]]
# Fitness after generation:
#  [290. 267. 291.]
# Iteration: 89 Generation: 6
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  5.]
#  [ 7. 23.  9.  5.]]
# Fitness before generation:
#  [290. 267. 291.]
# Find interval of 341
# Find interval of 30
# Parents:
#  [[ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [267. 290. 290.]
# Iteration: 89 Generation: 7
# Population before generation:
#  [[ 7. 23. 10.  5.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [267. 290. 290.]
# Find interval of 774
# Find interval of 376
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 8
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 773
# Find interval of 309
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 9
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 836
# Find interval of 491
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 10
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 605
# Find interval of 422
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 11
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 771
# Find interval of 303
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 12
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 801
# Find interval of 380
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 13
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 717
# Find interval of 162
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 89 Generation: 14
# Population before generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness before generation:
#  [290. 290. 290.]
# Find interval of 51
# Find interval of 241
# Parents:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Crossover and tries to cross:
#  [[ 7. 23. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23. 10.  4.]] [1000.]
# Population after generation:
#  [[ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]
#  [ 7. 23. 10.  4.]]
# Fitness after generation:
#  [290. 290. 290.]
# Iteration: 90 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 92
# Find interval of 30
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  8.]] [2.]
# tries 19.0
# Mutation and tries to mutate:
#  [[10. 24. 10.  7.]] [19.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24. 10.  7.]]
# Fitness after generation:
#  [104.  95.  79.]
# Iteration: 90 Generation: 1
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [10. 24. 10.  7.]]
# Fitness before generation:
#  [104.  95.  79.]
# Find interval of 236
# Find interval of 57
# Parents:
#  [[10. 24. 10.  7.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  8.]] [1.]
# tries 34.0
# Mutation and tries to mutate:
#  [[10. 24.  8.  8.]] [34.]
# Population after generation:
#  [[10. 24. 10.  7.]
#  [10. 24.  8.  8.]
#  [10. 24.  8.  8.]]
# Fitness after generation:
#  [ 79. 104. 104.]
# Iteration: 90 Generation: 2
# Population before generation:
#  [[10. 24. 10.  7.]
#  [10. 24.  8.  8.]
#  [10. 24.  8.  8.]]
# Fitness before generation:
#  [ 79. 104. 104.]
# Find interval of 253
# Find interval of 159
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [1.]
# tries 4.0
# Mutation and tries to mutate:
#  [[10. 24.  7.  8.]] [4.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness after generation:
#  [104. 104. 128.]
# Iteration: 90 Generation: 3
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness before generation:
#  [104. 104. 128.]
# Find interval of 185
# Find interval of 74
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [1.]
# tries 2.0
# Mutation and tries to mutate:
#  [[10. 23.  8.  8.]] [2.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 23.  8.  8.]]
# Fitness after generation:
#  [104. 104. 138.]
# Iteration: 90 Generation: 4
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 23.  8.  8.]]
# Fitness before generation:
#  [104. 104. 138.]
# Find interval of 1
# Find interval of 69
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [1.]
# tries 1.0
# Mutation and tries to mutate:
#  [[10. 24.  7.  8.]] [1.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness after generation:
#  [104. 104. 128.]
# Iteration: 90 Generation: 5
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness before generation:
#  [104. 104. 128.]
# Find interval of 134
# Find interval of 219
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  7.  8.]] [1.]
# tries 1.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  8.]] [1.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness after generation:
#  [104. 128. 264.]
# Iteration: 90 Generation: 6
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness before generation:
#  [104. 128. 264.]
# Find interval of 89
# Find interval of 137
# Parents:
#  [[10. 24.  8.  8.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  8.  8.]] [1.]
# tries 6.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  8.]] [6.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness after generation:
#  [104. 264. 264.]
# Iteration: 90 Generation: 7
# Population before generation:
#  [[10. 24.  8.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness before generation:
#  [104. 264. 264.]
# Find interval of 602
# Find interval of 337
# Parents:
#  [[10. 20.  7.  8.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  8.]] [1.]
# tries 131.0
# Mutation and tries to mutate:
#  [[10. 20.  6.  8.]] [131.]
# Population after generation:
#  [[10. 20.  7.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness after generation:
#  [264. 264. 288.]
# Iteration: 90 Generation: 8
# Population before generation:
#  [[10. 20.  7.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness before generation:
#  [264. 264. 288.]
# Find interval of 563
# Find interval of 12
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  6.  8.]] [1000.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness after generation:
#  [288. 264. 288.]
# Iteration: 90 Generation: 9
# Population before generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness before generation:
#  [288. 264. 288.]
# Find interval of 47
# Find interval of 204
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  8.]] [1.]
# tries 15.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [15.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [288. 264. 287.]
# Iteration: 90 Generation: 10
# Population before generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [288. 264. 287.]
# Find interval of 18
# Find interval of 166
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  6.  8.]] [1000.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness after generation:
#  [288. 264. 288.]
# Iteration: 90 Generation: 11
# Population before generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Fitness before generation:
#  [288. 264. 288.]
# Find interval of 401
# Find interval of 504
# Parents:
#  [[10. 20.  7.  8.]
#  [10. 20.  6.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  8.]] [1.]
# tries 48.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [48.]
# Population after generation:
#  [[10. 20.  7.  8.]
#  [10. 20.  6.  8.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [264. 288. 287.]
# Iteration: 90 Generation: 12
# Population before generation:
#  [[10. 20.  7.  8.]
#  [10. 20.  6.  8.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [264. 288. 287.]
# Find interval of 311
# Find interval of 433
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  8.]] [2.]
# tries 118.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [118.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [288. 287. 287.]
# Iteration: 90 Generation: 13
# Population before generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [288. 287. 287.]
# Find interval of 123
# Find interval of 98
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  6.  8.]] [2.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  6.  8.]] [1000.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]
#  [10. 20.  6.  8.]]
# Fitness after generation:
#  [288. 287. 288.]
# Iteration: 90 Generation: 14
# Population before generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  7.  7.]
#  [10. 20.  6.  8.]]
# Fitness before generation:
#  [288. 287. 288.]
# Find interval of 211
# Find interval of 334
# Parents:
#  [[10. 20.  6.  8.]
#  [10. 20.  6.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  6.  8.]] [1000.]
# Population after generation:
#  [[10. 20.  6.  8.]
#  [10. 20.  6.  8.]
#  [10. 20.  6.  8.]]
# Fitness after generation:
#  [288. 288. 288.]
# Iteration: 91 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 179
# Find interval of 47
# Parents:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  8.]] [3.]
# tries 6.0
# Mutation and tries to mutate:
#  [[25.  9.  6.  8.]] [6.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [25.  9.  6.  8.]]
# Fitness after generation:
#  [ 95. 104. 122.]
# Iteration: 91 Generation: 1
# Population before generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [25.  9.  6.  8.]]
# Fitness before generation:
#  [ 95. 104. 122.]
# Find interval of 180
# Find interval of 143
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  6.  8.]] [5.]
# tries 18.0
# Mutation and tries to mutate:
#  [[ 7. 24.  6.  8.]] [18.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Fitness after generation:
#  [104. 122. 260.]
# Iteration: 91 Generation: 2
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Fitness before generation:
#  [104. 122. 260.]
# Find interval of 274
# Find interval of 147
# Parents:
#  [[ 7. 24.  6.  8.]
#  [25.  9.  6.  8.]]
# Crossover and tries to cross:
#  [[25.  9.  6.  8.]] [2.]
# tries 18.0
# Mutation and tries to mutate:
#  [[25.  8.  6.  8.]] [18.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  8.  6.  8.]]
# Fitness after generation:
#  [260. 122. 156.]
# Iteration: 91 Generation: 3
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [25.  9.  6.  8.]
#  [25.  8.  6.  8.]]
# Fitness before generation:
#  [260. 122. 156.]
# Find interval of 126
# Find interval of 183
# Parents:
#  [[ 7. 24.  6.  8.]
#  [25.  8.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 78.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [78.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [25.  8.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [260. 156. 294.]
# Iteration: 91 Generation: 4
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [25.  8.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [260. 156. 294.]
# Find interval of 12
# Find interval of 446
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 23.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [260. 294. 294.]
# Iteration: 91 Generation: 5
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [260. 294. 294.]
# Find interval of 270
# Find interval of 132
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 185.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [185.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 260. 294.]
# Iteration: 91 Generation: 6
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 260. 294.]
# Find interval of 577
# Find interval of 247
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 23.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 260. 294.]
# Iteration: 91 Generation: 7
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 260. 294.]
# Find interval of 675
# Find interval of 131
# Parents:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 74.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [74.]
# Population after generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [294. 260. 294.]
# Iteration: 91 Generation: 8
# Population before generation:
#  [[ 7. 23.  6.  8.]
#  [ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [294. 260. 294.]
# Find interval of 388
# Find interval of 283
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 63.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [63.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [260. 294. 294.]
# Iteration: 91 Generation: 9
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [260. 294. 294.]
# Find interval of 245
# Find interval of 334
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 23.  6.  8.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 7. 23.  6.  8.]] [1000.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness after generation:
#  [260. 294. 294.]
# Iteration: 91 Generation: 10
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Fitness before generation:
#  [260. 294. 294.]
# Find interval of 136
# Find interval of 550
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 51.0
# Mutation and tries to mutate:
#  [[ 6. 24.  6.  8.]] [51.]
# Population after generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness after generation:
#  [260. 294. 296.]
# Iteration: 91 Generation: 11
# Population before generation:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]
#  [ 6. 24.  6.  8.]]
# Fitness before generation:
#  [260. 294. 296.]
# Find interval of 99
# Find interval of 102
# Parents:
#  [[ 7. 24.  6.  8.]
#  [ 7. 23.  6.  8.]]
# Crossover and tries to cross:
#  [[ 7. 24.  6.  8.]] [1.]
# tries 15.0
# ...
#  [288. 288. 288.]
# Iteration: 97 Generation: 14
# Population before generation:
#  [[ 8. 22. 10.  4.]
#  [ 8. 22. 10.  4.]
#  [ 8. 22. 10.  4.]]
# Fitness before generation:
#  [288. 288. 288.]
# Find interval of 232
# Find interval of 229
# Parents:
#  [[ 8. 22. 10.  4.]
#  [ 8. 22. 10.  4.]]
# Crossover and tries to cross:
#  [[ 8. 22. 10.  4.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[ 8. 22. 10.  4.]] [1000.]
# Population after generation:
#  [[ 8. 22. 10.  4.]
#  [ 8. 22. 10.  4.]
#  [ 8. 22. 10.  4.]]
# Fitness after generation:
#  [288. 288. 288.]
# Iteration: 98 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 43
# Find interval of 53
# Parents:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  5.]] [1.]
# tries 12.0
# Mutation and tries to mutate:
#  [[24.  9. 10.  5.]] [12.]
# Population after generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [24.  9. 10.  5.]]
# Fitness after generation:
#  [104.  95. 131.]
# Iteration: 98 Generation: 1
# Population before generation:
#  [[10. 24.  8.  8.]
#  [25.  9. 10.  5.]
#  [24.  9. 10.  5.]]
# Fitness before generation:
#  [104.  95. 131.]
# Find interval of 318
# Find interval of 184
# Parents:
#  [[24.  9. 10.  5.]
#  [25.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9. 10.  5.]] [1.]
# tries 62.0
# Mutation and tries to mutate:
#  [[25.  9.  9.  5.]] [62.]
# Population after generation:
#  [[24.  9. 10.  5.]
#  [25.  9. 10.  5.]
#  [25.  9.  9.  5.]]
# Fitness after generation:
#  [131.  95. 119.]
# Iteration: 98 Generation: 2
# Population before generation:
#  [[24.  9. 10.  5.]
#  [25.  9. 10.  5.]
#  [25.  9.  9.  5.]]
# Fitness before generation:
#  [131.  95. 119.]
# Find interval of 293
# Find interval of 70
# Parents:
#  [[25.  9.  9.  5.]
#  [24.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[25.  9.  9.  5.]] [1.]
# tries 65.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [65.]
# Population after generation:
#  [[25.  9.  9.  5.]
#  [24.  9. 10.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [119. 131. 255.]
# Iteration: 98 Generation: 3
# Population before generation:
#  [[25.  9.  9.  5.]
#  [24.  9. 10.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [119. 131. 255.]
# Find interval of 312
# Find interval of 130
# Parents:
#  [[25.  5.  9.  5.]
#  [24.  9. 10.  5.]]
# Crossover and tries to cross:
#  [[24.  9.  9.  5.]] [1.]
# tries 28.0
# Mutation and tries to mutate:
#  [[23.  9.  9.  5.]] [28.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [24.  9. 10.  5.]
#  [23.  9.  9.  5.]]
# Fitness after generation:
#  [255. 131. 191.]
# Iteration: 98 Generation: 4
# Population before generation:
#  [[25.  5.  9.  5.]
#  [24.  9. 10.  5.]
#  [23.  9.  9.  5.]]
# Fitness before generation:
#  [255. 131. 191.]
# Find interval of 371
# Find interval of 14
# Parents:
#  [[24.  9. 10.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[24.  9.  9.  5.]] [1.]
# tries 36.0
# Mutation and tries to mutate:
#  [[23.  9.  9.  5.]] [36.]
# Population after generation:
#  [[24.  9. 10.  5.]
#  [25.  5.  9.  5.]
#  [23.  9.  9.  5.]]
# Fitness after generation:
#  [131. 255. 191.]
# Iteration: 98 Generation: 5
# Population before generation:
#  [[24.  9. 10.  5.]
#  [25.  5.  9.  5.]
#  [23.  9.  9.  5.]]
# Fitness before generation:
#  [131. 255. 191.]
# Find interval of 204
# Find interval of 302
# Parents:
#  [[25.  5.  9.  5.]
#  [23.  9.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [23.  9.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 191. 255.]
# Iteration: 98 Generation: 6
# Population before generation:
#  [[25.  5.  9.  5.]
#  [23.  9.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 191. 255.]
# Find interval of 69
# Find interval of 264
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 7
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 110
# Find interval of 54
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 8
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 745
# Find interval of 53
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 9
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 459
# Find interval of 246
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 10
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 179
# Find interval of 276
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 11
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 429
# Find interval of 54
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 12
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 460
# Find interval of 283
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 13
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 122
# Find interval of 126
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 98 Generation: 14
# Population before generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness before generation:
#  [255. 255. 255.]
# Find interval of 498
# Find interval of 392
# Parents:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Crossover and tries to cross:
#  [[25.  5.  9.  5.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[25.  5.  9.  5.]] [1000.]
# Population after generation:
#  [[25.  5.  9.  5.]
#  [25.  5.  9.  5.]
#  [25.  5.  9.  5.]]
# Fitness after generation:
#  [255. 255. 255.]
# Iteration: 99 Generation: 0
# Population before generation:
#  [[10. 24.  8.  8.]
#  [29. 19. 10. 11.]
#  [25.  9. 10.  5.]]
# Fitness before generation:
#  [104.   0.  95.]
# Find interval of 130
# Find interval of 36
# Parents:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  8.]] [3.]
# tries 5.0
# Mutation and tries to mutate:
#  [[10. 20. 10.  8.]] [5.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [10. 20. 10.  8.]]
# Fitness after generation:
#  [ 95. 104. 192.]
# Iteration: 99 Generation: 1
# Population before generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [10. 20. 10.  8.]]
# Fitness before generation:
#  [ 95. 104. 192.]
# Find interval of 60
# Find interval of 80
# Parents:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24. 10.  5.]] [5.]
# tries 21.0
# Mutation and tries to mutate:
#  [[ 7. 24. 10.  5.]] [21.]
# Population after generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [ 7. 24. 10.  5.]]
# Fitness after generation:
#  [ 95. 104. 233.]
# Iteration: 99 Generation: 2
# Population before generation:
#  [[25.  9. 10.  5.]
#  [10. 24.  8.  8.]
#  [ 7. 24. 10.  5.]]
# Fitness before generation:
#  [ 95. 104. 233.]
# Find interval of 285
# Find interval of 174
# Parents:
#  [[ 7. 24. 10.  5.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  8.  8.]] [1.]
# tries 21.0
# Mutation and tries to mutate:
#  [[10. 24.  7.  8.]] [21.]
# Population after generation:
#  [[ 7. 24. 10.  5.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness after generation:
#  [233. 104. 128.]
# Iteration: 99 Generation: 3
# Population before generation:
#  [[ 7. 24. 10.  5.]
#  [10. 24.  8.  8.]
#  [10. 24.  7.  8.]]
# Fitness before generation:
#  [233. 104. 128.]
# Find interval of 380
# Find interval of 314
# Parents:
#  [[10. 24.  7.  8.]
#  [10. 24.  8.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  7.  8.]] [1.]
# tries 11.0
# Mutation and tries to mutate:
#  [[10. 23.  7.  8.]] [11.]
# Population after generation:
#  [[10. 24.  7.  8.]
#  [10. 24.  8.  8.]
#  [10. 23.  7.  8.]]
# Fitness after generation:
#  [128. 104. 162.]
# Iteration: 99 Generation: 4
# Population before generation:
#  [[10. 24.  7.  8.]
#  [10. 24.  8.  8.]
#  [10. 23.  7.  8.]]
# Fitness before generation:
#  [128. 104. 162.]
# Find interval of 312
# Find interval of 1
# Parents:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  7.  8.]] [1.]
# tries 37.0
# Mutation and tries to mutate:
#  [[10. 24.  6.  8.]] [37.]
# Population after generation:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 24.  6.  8.]]
# Fitness after generation:
#  [162. 128. 152.]
# Iteration: 99 Generation: 5
# Population before generation:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 24.  6.  8.]]
# Fitness before generation:
#  [162. 128. 152.]
# Find interval of 150
# Find interval of 25
# Parents:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 24.  7.  8.]] [1.]
# tries 14.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  8.]] [14.]
# Population after generation:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness after generation:
#  [162. 128. 264.]
# Iteration: 99 Generation: 6
# Population before generation:
#  [[10. 23.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  8.]]
# Fitness before generation:
#  [162. 128. 264.]
# Find interval of 476
# Find interval of 252
# Parents:
#  [[10. 20.  7.  8.]
#  [10. 24.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  8.]] [1.]
# tries 52.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [52.]
# Population after generation:
#  [[10. 20.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [264. 128. 287.]
# Iteration: 99 Generation: 7
# Population before generation:
#  [[10. 20.  7.  8.]
#  [10. 24.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [264. 128. 287.]
# Find interval of 664
# Find interval of 56
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  8.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 264. 287.]
# Iteration: 99 Generation: 8
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  8.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 264. 287.]
# Find interval of 239
# Find interval of 385
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 9
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 505
# Find interval of 533
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 10
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 197
# Find interval of 417
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 11
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 248
# Find interval of 407
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 12
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 367
# Find interval of 508
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 13
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 237
# Find interval of 52
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# Iteration: 99 Generation: 14
# Population before generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness before generation:
#  [287. 287. 287.]
# Find interval of 342
# Find interval of 516
# Parents:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Crossover and tries to cross:
#  [[10. 20.  7.  7.]] [1.]
# tries 1000.0
# Mutation and tries to mutate:
#  [[10. 20.  7.  7.]] [1000.]
# Population after generation:
#  [[10. 20.  7.  7.]
#  [10. 20.  7.  7.]
#  [10. 20.  7.  7.]]
# Fitness after generation:
#  [287. 287. 287.]
# The algorithm takes 112.53 seconds for process
# The chromosome [ 6. 24.  6.  8.] has the maximum fitness of 296.0

# %% [markdown]
# ## Plot

# %% [markdown]
# ### Funktion

# %% [markdown]
# Die Funktion `multiple_plot()` zeigt Diagramme an, die relevant sind bei der Ausführung mehrerer Iterationen.

# %%
def multiple_plot():
    plot(np.true_divide(population_fitness_after_sum.sum(axis=0), number_iterations), "Sum of fitness of each generation - average", "Generations", "Fitness")
    plot(np.true_divide(best_fitness_after.sum(axis=0), number_iterations), "Best fitness value of each generation - average", "Generations", "Fitness")
    plot(np.true_divide(tries_mutation_list.sum(axis=0), number_iterations), "Numbers of tries to mutate children - average", "Generations", "Tries to mutate")
    plot(np.true_divide(tries_crossover_list.sum(axis=0), number_iterations), "Numbers of tries to cross parents - average", "Generations", "Tries to cross")
    costs_sum_average = np.zeros((number_generations, 4))
    costs_best_average = np.zeros((number_generations, 4))
    for i in range(number_iterations):
        for g in range(number_generations):
            costs_sum_average[g] += costs_sum_list[i][g]
            costs_best_average[g] += costs_max_list[i][g]
    plot(np.true_divide(costs_sum_average, number_iterations), "Sum of costs of each generation - average", "Generations", "Costs")
    plot(np.true_divide(costs_best_average, number_iterations), "Costs of best chromosomes - average", "Generations", "Costs")

    fig, ax1 = plt.subplots()
    ax1.boxplot(best_chromosome_of_iteration)
    ax1.set_title = "Best chromosomes of each iteration"
    ax1.set_xlabel('Gen of chromosome')
    ax1.set_ylabel('Value of gen')
    plt.show()

# %% [markdown]
# ### Beispiel

# %% [markdown]
# Der folgende Abschnitt zeigt die Daten des vorherigen Beispiels an. Das erste Diagramm beschreibt den durchschnittlichen Verlauf der Summe der Fitness-Werte der Generationen. Die zweite Grafik zeigt die durchschnittliche Fitness der besten Chromosome jeder Generation. Danach folgen die durchschnittliche Anzahl an Versuchen, ein Elternpaar zu kreuzen und deren Nachfolger zu mutieren. Abbildungen 5 und 6 zeigen die durchschnittlichen Kosten jeder Generation und der besten Chromosome. Die letzte Grafik zeigt die Verteilungen der besten Chromosome jeder Iteration an.

# %%
multiple_plot()

# %% [markdown]
# # 11. Skalierung

# %% [markdown]
# ## 11.1 Beispiel

# %% [markdown]
# Der Algorithmus kann unterschiedliche Anzahlen an Lieferanten und Produkten verarbeiten. Das folgende Beispiel beschreibt den Fall, dass drei Lieferanten vier Produkte anbieten. Zusätzlich besteht die Population aus vier Chromosomen.

# %%
seed_number = 1
np.random.seed(seed_number)
selling_price = np.array([13, 9, 12, 17])
supplier_price = np.array([[6, 4, 5, 9], [4, 3, 4, 13], [7, 5, 4, 10]])
transaction_cost = np.array([10, 30, 40])
holding_cost = np.array([30, 20, 15, 12])
demands = np.array([30, 14, 7, 10])
number_products = len(selling_price)
number_suppliers = len(supplier_price)
population_size = 4
lower_bound = 0
upper_bound = np.array([50, 34, 27, 30])
number_iterations = 1
number_generations = 15
penalty = 99999

chromosome_size = number_suppliers * number_products
init_population = np.zeros((population_size, number_suppliers * number_products))
init_population[0] = [8, 10, 12, 5, 7, 4, 2, 6, 4, 4, 8, 2]
init_population[1] = [20, 5, 8, 12, 2, 3, 8, 0, 0, 2, 3, 8]
init_population[2] = [2, 27, 6, 5, 5, 5, 4, 5, 2, 9, 1, 3]
init_population[3] = [10, 2, 19, 2, 6, 13, 3, 0, 5, 4, 5, 6]
number_parents = (population_size // 2) + (population_size % 2)
number_children = (population_size - number_parents)

population_before = np.zeros((number_iterations, number_generations, population_size, chromosome_size))
population_fitness_before = np.zeros((number_iterations, number_generations, population_size))
population_after = np.zeros((number_iterations, number_generations, population_size, chromosome_size))
population_fitness_after = np.zeros((number_iterations, number_generations, population_size))
population_fitness_after_sum = np.zeros((number_iterations, number_generations))
best_chromosomes_after = np.zeros((number_iterations, number_generations, chromosome_size))
best_fitness_after = np.zeros((number_iterations, number_generations))
best_chromosome_of_iteration = np.zeros((number_iterations, chromosome_size))
best_fitness_of_iteration = np.zeros(number_iterations)

parents_list = np.zeros((number_iterations, number_generations, number_parents, chromosome_size))
crossover_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))
tries_crossover_list = np.zeros((number_iterations, number_generations, number_children))
mutation_list = np.zeros((number_iterations, number_generations, number_children, chromosome_size))
tries_mutation_list = np.zeros((number_iterations, number_generations, number_children))

costs_list = np.zeros((number_iterations, number_generations, population_size, 4))
costs_max_list = np.zeros((number_iterations, number_generations, 4))
costs_sum_list = np.zeros((number_iterations, number_generations, 4))

# %% [markdown]
# ### 11.1.1 Population

# %% [markdown]
# Die Erhöhung der Lieferantenanzahl und Produktanzahl erschwert den Prozess der Generierung einer zufälligen Population. Der Algorithmus muss mehr Gene bestimmen, welche zu einem positiven Fitness-Wert führen. Im Szenario mit drei Lieferanten und vier Produkten sind es 12 Gene. Die Implementierung zur Erzeugung einer Ausgangspopulation endet mit einer Population, in der mindestens ein Chromosom mit positivem Fitness-Wert existiert. Dadurch entsteht in diesem Szenario meist eine Population mit nur einem positiven Chromosom, welches sich kreuzt, sodass die Lösungen am Ende kaum vom Anfang unterscheiden. Von 100 generierten Populationen haben lediglich sechs Populationen mehr als ein Chromosom mit positiver Fitness. Dies verfehlt die Idee eines genetischen Algorithmus. Dieses Ergebnis bezieht sich auf Seed-Nummer 1.

# %%
seed_number = 1
number_positive_chroms = 0  # Anzahl an positiven Chromosomen
number_negative_chroms = 0  # Anzahl an negativen Chromosomen
for counter in range(100):  # Prüfen von Populationen
    np.random.seed(counter)
    example_population = random_population()  # Population erzeugen
    fitness_sum = 0
    for chrom in example_population:  # Summe der Fitness-Werte der Chromosome berechnen
        fitness_sum += calculate_fitness(chrom)
    while fitness_sum <= 0:  #  Neue Population erzeugen, solange kein positives Chromosom vorhanden ist
        fitness_sum = 0
        example_population = random_population()
        for chrom in example_population:
            fitness_sum += calculate_fitness(chrom)
    print("Population:", counter)
    for chrom in example_population:  
        fit = calculate_fitness(chrom)
        if fit == 0:  # Prüfen, wie viele Chromosome positiv/negativ sind
            number_negative_chroms += 1
        else:
            number_positive_chroms += 1
        print("Chromosom:", chrom, "Fitness:", calculate_fitness(chrom))  # Chromosome mit deren Fitness ausgeben
print(number_positive_chroms, "chromosomes have an positive fitness value.", number_negative_chroms, "chromosomes have an negative fitness value.")
# Out:
# Population: 0
# Chromosom: [28. 27. 15.  3.  3. 12.  3.  4.  4.  7.  8.  4.] Fitness: 0
# Chromosom: [ 3.  2. 25.  8. 12.  1.  4.  4.  2.  0.  8.  3.] Fitness: 41.0
# Chromosom: [ 9. 21.  5.  1.  7. 13.  6.  0.  6.  4.  7.  3.] Fitness: 0
# Chromosom: [21. 27. 12.  5. 11. 11.  6.  1.  3.  7.  5.  5.] Fitness: 0
# Population: 1
# Chromosom: [25. 16. 28.  2.  0. 13.  2.  4.  1.  7.  9.  8.] Fitness: 0
# Chromosom: [10. 28. 20. 12.  9.  8.  2.  4.  4.  7.  2.  6.] Fitness: 0
# Chromosom: [22.  6.  2.  7.  7.  0.  6.  5.  1.  4.  6.  0.] Fitness: 228.0
# Chromosom: [22.  5. 13.  5.  4. 10.  1.  6.  5.  4.  4.  6.] Fitness: 0
# Population: 2
# Chromosom: [ 9. 14. 28. 11.  0. 10.  6.  2.  0.  2.  9.  6.] Fitness: 0
# Chromosom: [ 5.  6. 22.  6.  3.  8.  2.  1.  4.  8.  1.  6.] Fitness: 24.0
# 106 chromosomes have an positive fitness value. 294 chromosomes have an negative fitness value.

# %% [markdown]
# ### 11.1.2 Laufzeit

# %% [markdown]
# Darüber hinaus ist mit einem Anstieg der Laufzeit zu rechnen. Das Beispiel aus Kapitel 9 mit zwei Produkten, zwei Lieferanten und einer zufällig generierten Population mit drei Chromosomen benötigt 0,5 Sekunden für eine Iteration. Dieses Beispiel benötigt bei einer gegebenen Population 0,8 Sekunden. Ist die Population nicht vorgegeben benötigt der Algorithmus über 2 Sekunden, sodass eine Erweiterung um mehr Lieferanten und Produkten zu längeren Laufzeiten führt.

# %%
# seed_number = 1
# np.random.seed(seed_number)
start_time = time.time()
# example_population = random_population() # Der Fall, wenn Population zufällig generiert werden soll
example_population = init_population
main_part(number_generations, example_population)
end_time = time.time()
print("The algorithm takes", "{:.2f}".format(end_time - start_time), "seconds for process")

if number_iterations >= 2:
    print("The chromosome", best_chromosome_of_iteration[np.argmax(best_fitness_of_iteration)],
          "has the maximum fitness of", np.amax(best_fitness_of_iteration))
else:
    print("The chromosome", best_chromosome_of_iteration, "has the maximum fitness of", best_fitness_of_iteration)
# Out:
# Iteration: 0 Generation: 0
# Population before generation:
#  [[ 8. 10. 12.  5.  7.  4.  2.  6.  4.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [ 2. 27.  6.  5.  5.  5.  4.  5.  2.  9.  1.  3.]
#  [10.  2. 19.  2.  6. 13.  3.  0.  5.  4.  5.  6.]]
# Fitness before generation:
#  [84. 47. 30.  0.]
# Find interval of 38
# Find interval of 13
# Parents:
#  [[ 8. 10. 12.  5.  7.  4.  2.  6.  4.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  2.  3.  2.  6.  0.  4.  8.  2.]
#  [ 8. 10. 12. 12.  2.  3.  8.  0.  4.  4.  3.  8.]] [23. 71.]
# tries 2.0
# tries 3.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [ 8. 10. 12. 12.  2.  3.  8.  0.  4.  1.  3.  8.]] [2. 3.]
# Population after generation:
#  [[ 8. 10. 12.  5.  7.  4.  2.  6.  4.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [ 8. 10. 12. 12.  2.  3.  8.  0.  4.  1.  3.  8.]]
# Fitness after generation:
#  [ 84.  47.  41. 106.]
# Iteration: 0 Generation: 1
# Population before generation:
#  [[ 8. 10. 12.  5.  7.  4.  2.  6.  4.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [ 8. 10. 12. 12.  2.  3.  8.  0.  4.  1.  3.  8.]]
# Fitness before generation:
#  [ 84.  47.  41. 106.]
# Find interval of 98
# Find interval of 119
# Parents:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  3.  8.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]] [1. 1.]
# tries 17.0
# tries 12.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 10.  1.  3.  2.  6.  0.  4.  3.  8.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  5.]] [17. 12.]
# Population after generation:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 10.  1.  3.  2.  6.  0.  4.  3.  8.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  5.]]
# Fitness after generation:
#  [ 47.  41.  82. 113.]
# Iteration: 0 Generation: 2
# Population before generation:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 10.  1.  3.  2.  6.  0.  4.  3.  8.]
#  [20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  5.]]
# Fitness before generation:
#  [ 47.  41.  82. 113.]
# Find interval of 29
# Find interval of 20
# Parents:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  8.  0.  0.  2.  8.  2.]] [2. 2.]
# tries 32.0
# tries 25.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  8.  0.  0.  0.  8.  2.]] [32. 25.]
# Population after generation:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  8.  0.  0.  0.  8.  2.]]
# Fitness after generation:
#  [ 47.  41. 110. 119.]
# Iteration: 0 Generation: 3
# Population before generation:
#  [[20.  5.  8. 12.  2.  3.  8.  0.  0.  2.  3.  8.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  8.  0.  0.  0.  8.  2.]]
# Fitness before generation:
#  [ 47.  41. 110. 119.]
# Find interval of 51
# Find interval of 91
# Parents:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]] [1. 1.]
# tries 9.0
# tries 3.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  7.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]] [9. 3.]
# Population after generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  7.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]]
# Fitness after generation:
#  [ 41. 110. 108. 141.]
# Iteration: 0 Generation: 4
# Population before generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  2.  3.  2.  6.  0.  2.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  7.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]]
# Fitness before generation:
#  [ 41. 110. 108. 141.]
# Find interval of 16
# Find interval of 281
# Parents:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]] [1. 1.]
# tries 16.0
# tries 2.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]] [16.  2.]
# Population after generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Fitness after generation:
#  [ 41. 141.  91.  83.]
# Iteration: 0 Generation: 5
# Population before generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  6.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Fitness before generation:
#  [ 41. 141.  91.  83.]
# Find interval of 334
# Find interval of 107
# Parents:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  8.  2.]] [1. 1.]
# tries 66.0
# tries 35.0
# Mutation and tries to mutate:
#  [[17.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  5. 12.  1.  3.  2.  6.  0.  4.  8.  2.]] [66. 35.]
# Population after generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [17.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  5. 12.  1.  3.  2.  6.  0.  4.  8.  2.]]
# Fitness after generation:
#  [ 83. 141. 249. 152.]
# Iteration: 0 Generation: 6
# Population before generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [17.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  5. 12.  1.  3.  2.  6.  0.  4.  8.  2.]]
# Fitness before generation:
#  [ 83. 141. 249. 152.]
# Find interval of 140
# Find interval of 70
# Parents:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]] [1. 1.]
# tries 95.0
# tries 11.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 11.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]] [95. 11.]
# Population after generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 11.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]]
# Fitness after generation:
#  [141.  83. 165. 102.]
# Iteration: 0 Generation: 7
# Population before generation:
#  [[20.  5.  8. 12.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 11.  1.  3.  2.  6.  0.  4.  4.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]]
# Fitness before generation:
#  [141.  83. 165. 102.]
# Find interval of 401
# Find interval of 181
# Parents:
#  [[20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Crossover and tries to cross:
#  [[20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]] [1. 1.]
# tries 78.0
# tries 11.0
# Mutation and tries to mutate:
#  [[20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]] [78. 11.]
# Population after generation:
#  [[20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Fitness after generation:
#  [102.  83. 124. 185.]
# Iteration: 0 Generation: 8
# Population before generation:
#  [[20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]]
# Fitness before generation:
#  [102.  83. 124. 185.]
# Find interval of 437
# Find interval of 217
# Parents:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]] [1. 1.]
# tries 49.0
# tries 99.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]] [49. 99.]
# Population after generation:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [185. 124. 251. 251.]
# Iteration: 0 Generation: 9
# Population before generation:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  5.  8. 12.  1.  3.  2.  5.  0.  2.  8.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [185. 124. 251. 251.]
# Find interval of 102
# Find interval of 198
# Parents:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]] [1. 1.]
# tries 7.0
# tries 82.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]] [ 7. 82.]
# Population after generation:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [185. 251. 257. 276.]
# Iteration: 0 Generation: 10
# Population before generation:
#  [[20.  2.  8. 12.  1.  3.  2.  6.  0.  2.  8.  2.]
#  [20.  2.  8. 12.  1.  3.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [185. 251. 257. 276.]
# Find interval of 620
# Find interval of 587
# Parents:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]] [1. 1.]
# tries 12.0
# tries 103.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  0.  2.  2.  5.  0.  2.  7.  1.]] [ 12. 103.]
# Population after generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  0.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [257. 276. 276. 299.]
# Iteration: 0 Generation: 11
# Population before generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  0.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [257. 276. 276. 299.]
# Find interval of 111
# Find interval of 462
# Parents:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]] [1. 1.]
# tries 1.0
# tries 23.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 12.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]] [ 1. 23.]
# Population after generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [257. 276. 277. 300.]
# Iteration: 0 Generation: 12
# Population before generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [257. 276. 277. 300.]
# Find interval of 1013
# Find interval of 26
# Parents:
#  [[20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 11.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  5.  0.  2.  7.  1.]] [1. 1.]
# tries 27.0
# tries 186.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]] [ 27. 186.]
# Population after generation:
#  [[20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [300. 257. 301. 300.]
# Iteration: 0 Generation: 13
# Population before generation:
#  [[20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]
#  [20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [300. 257. 301. 300.]
# Find interval of 317
# Find interval of 379
# Parents:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 12.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  6.  0.  2.  7.  1.]] [1. 1.]
# tries 88.0
# tries 30.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]] [88. 30.]
# Population after generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness after generation:
#  [257. 301. 301. 300.]
# Iteration: 0 Generation: 14
# Population before generation:
#  [[20.  2.  8. 12.  1.  2.  2.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  2.  5.  0.  2.  7.  1.]]
# Fitness before generation:
#  [257. 301. 301. 300.]
# Find interval of 454
# Find interval of 449
# Parents:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]]
# Crossover and tries to cross:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]] [1. 1.]
# tries 1000.0
# tries 1000.0
# Mutation and tries to mutate:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]] [1000. 1000.]
# Population after generation:
#  [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]
#  [20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]]
# Fitness after generation:
#  [301. 301. 301. 301.]
# The algorithm takes 0.78 seconds for process
# The chromosome [[20.  2.  8. 11.  1.  2.  1.  6.  0.  2.  7.  1.]] has the maximum fitness of [301.]
